# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from math import floor

# %%
dates_all = [
    ['3_11', '2020-03-11'],
    ['3_10', '2020-03-10'],
    ['3_9', '2020-03-09'],
    ['3_8', '2020-03-08'],
    ['3_7', '2020-03-07'],
    ['3_6', '2020-03-06'],
    ['3_5', '2020-03-05'],
    ['3_4', '2020-03-04'],
    ['3_3', '2020-03-03'],
    ['3_2', '2020-03-02'],
    ['3_1', '2020-03-01'],
    ['2_29', '2020-02-29'],
    ['2_28', '2020-02-28'],
    ['2_27', '2020-02-27'],
    ['2_26', '2020-02-26'],
    ['2_25', '2020-02-25'],
    ['2_24', '2020-02-24'],
    ['2_23', '2020-02-23'],
    ['2_22', '2020-02-22'],
    ['2_21', '2020-02-21'],
    ['2_20', '2020-02-20'],
#     ['2_13', '2020-02-13'],
    ['2_12', '2020-02-12'],
    ['2_11', '2020-02-11'],
    ['2_10', '2020-02-10'],
    ['2_9', '2020-02-09'],
    ['2_8', '2020-02-08'],
    ['2_7', '2020-02-07'],
    ['2_6', '2020-02-06'],
    ['2_5', '2020-02-05'],
    ['2_4', '2020-02-04'],
    ['2_3', '2020-02-03'],
    ['2_2', '2020-02-02'],
    ['2_1', '2020-02-01'],
    ['1_31', '2020-01-31'],
    ['1_30', '2020-01-30'],
    ['1_29', '2020-01-29'],
    ['1_28', '2020-01-28'],
    ['1_27', '2020-01-27'],
    ['1_26', '2020-01-26'],
    ['1_25', '2020-01-25'],
    ['1_24', '2020-01-24'],
    ['1_23', '2020-01-23'],
    ['1_22', '2020-01-22'],
    ['1_20', '2020-01-20'],
    ['1_19', '2020-01-19'],
    ['1_18', '2020-01-18'],
    ['1_17', '2020-01-17'],
    ['1_16', '2020-01-16'],
    ['1_15', '2020-01-15'],
    ['1_14', '2020-01-14'],
    ['1_13', '2020-01-13'],
    ['1_12', '2020-01-12'],
    ['1_11', '2020-01-11'],
    ['1_10', '2020-01-10'],
#     ['1_9', '2020-01-09'],
    ['1_8', '2020-01-08'],
    ['1_7', '2020-01-07'],
    ['1_6', '2020-01-06'],
    ['1_5', '2020-01-05'],
    ['1_4', '2020-01-04'],
    ['1_3', '2020-01-03'],
    ['1_2', '2020-01-02'],
    ['1_1', '2020-01-01'],
    ['12_31', '2019-12-31'],
    ['12_30', '2019-12-30'],
    ['12_29', '2019-12-29'],
    ['12_28', '2019-12-28'],
    ['12_27', '2019-12-27'],
    ['12_26', '2019-12-26'],
    ['12_25', '2019-12-25'],
    ['12_23', '2019-12-23'],
    ['12_22', '2019-12-22'],
    ['12_21', '2019-12-21'],
    ['12_20', '2019-12-20'],
    ['12_19', '2019-12-19'],
    ['12_18', '2019-12-18'],
    ['12_17', '2019-12-17'],
    ['12_16', '2019-12-16'],
    ['12_15', '2019-12-15'],
    ['12_14', '2019-12-14'],
    ['12_13', '2019-12-13'],
    ['12_12', '2019-12-12'],
    ['12_11', '2019-12-11'],
    ['12_10', '2019-12-10'],
    ['12_9', '2019-12-09'],
    ['12_8', '2019-12-08'],
    ['12_7', '2019-12-07'],
    ['12_6', '2019-12-06'],
    ['12_5', '2019-12-05'],
    ['12_4', '2019-12-04'],
    ['12_3', '2019-12-03'],
    ['12_2', '2019-12-02'],
    ['12_1', '2019-12-01'],
    ['11_30', '2019-11-30'],
    ['11_29', '2019-11-29'],
    ['11_27', '2019-11-27'],
    ['11_26', '2019-11-26'],
    ['11_25', '2019-11-25'],
    ['11_24', '2019-11-24'],
    ['11_23', '2019-11-23'],
    ['11_22', '2019-11-22'],
    ['11_21', '2019-11-21'],
    ['11_20', '2019-11-20'],
    ['11_19', '2019-11-19'],
    ['11_18', '2019-11-18'],
    ['11_17', '2019-11-17'],
    ['11_16', '2019-11-16'],
    ['11_15', '2019-11-15'],
    ['11_14', '2019-11-14'],
    ['11_13', '2019-11-13'],
#     ['11_12', '2019-11-12'],
    ['11_11', '2019-11-11'],
#     ['11_10', '2019-11-10'],
    ['11_9', '2019-11-09'],
    ['11_8', '2019-11-08'],
    ['11_7', '2019-11-07'],
    ['11_6', '2019-11-06'],
    ['11_5', '2019-11-05'],
    ['11_4', '2019-11-04'],
    ['11_3', '2019-11-03'],
    ['11_2', '2019-11-02'],
    ['11_1', '2019-11-01'],
    ['10_31', '2019-10-31'],
    ['10_30', '2019-10-30'],
    ['10_29', '2019-10-29'],
    ['10_28', '2019-10-28'],
    ['10_27', '2019-10-27'],
    ['10_26', '2019-10-26'],
#     ['10_25', '2019-10-25'],
#     ['10_24', '2019-10-24'],
#     ['10_23', '2019-10-23'],
#     ['10_22', '2019-10-22'],   
]

files= [
    'RandomlyCreatedLineups',
    'BestCreatedLineups_AvgProj_Baseline',
    'BestCreatedLineups_ElasticNet',
    'BestCreatedLineups_LinearRegression',
    'BestCreatedLineups_LinearRegression_400',
    'BestCreatedLineups_LinearRegression_800',
    'BestCreatedLineups'
]


def openMoneyLines():
    file_name = 'Metrics/MoneyLines.csv'
    file = pd.read_csv(file_name)
    return file

def openCreatedLineupsForDate(game_day, file_name):
    file_name = '{}/{}'.format(file_name, game_day)
    file = pd.read_csv(file_name,index_col=[0,1], skipinitialspace=True)
    return file

# %%
def constructDate(date):
    year = int(date[2:4])
    month = int(date[5:7])
    day = int(date[8:])
    return str(month)+'/'+str(day)+'/'+str(year)

def findLinesForDate(date, lines):
    gpp_line = lines[lines['Date'] == constructDate(date)]['GPP Line'].values[0]
    cash_line = lines[lines['Date'] == constructDate(date)]['Cash Line '].values[0]
    return gpp_line, cash_line

# %%
def calculateWL( selected_entries, 
                gpp_line, 
                cash_line, 
                cash_line_wins, 
                gpp_line_wins,
                cash_line_losses, 
                gpp_line_losses,
                top_three,
                tenth_place,
                fiftyth_place):
    for score in list(selected_entries.groupby(['Lineup Num'])['Actual FP'].sum()):
        if(score >= cash_line): 
            cash_line_wins = cash_line_wins + 1
        if(score < cash_line):
            cash_line_losses = cash_line_losses + 1
        if(score >= gpp_line): 
            gpp_line_wins = gpp_line_wins + 1
        if(score < gpp_line):
            gpp_line_losses = gpp_line_losses + 1
        if(score >= gpp_line+85): 
            top_three = top_three + 1
        if(score >= gpp_line+70): 
            tenth_place = tenth_place + 1
        if(score >= gpp_line+58): 
            fiftyth_place = fiftyth_place + 1
        
    return cash_line_wins, gpp_line_wins,cash_line_losses, gpp_line_losses, top_three, tenth_place, fiftyth_place

def calculateWinPercentage(cash_line_wins, gpp_line_wins,cash_line_losses, gpp_line_losses):
    cash_line_win_percent = (cash_line_wins / (cash_line_wins + cash_line_losses))*100
    gpp_line_win_percent = (gpp_line_wins / (gpp_line_wins + gpp_line_losses))*100
    total_win_percent = ((cash_line_wins + gpp_line_wins) / (cash_line_wins + cash_line_losses + gpp_line_wins + gpp_line_losses))*100
    return cash_line_win_percent, gpp_line_win_percent, total_win_percent
    
def calculateProfitability():
    lines = openMoneyLines()
    full_report = []
    for file_name in files:
        for selection in range(0,11):
            cash_line_wins = 0
            gpp_line_wins = 0
            cash_line_losses = 0
            gpp_line_losses = 0
            top_three = 0
            tenth_place=0
            fiftyth_place=0
            for game_day in dates_all:
                gpp_line, cash_line = findLinesForDate(game_day[1], lines)
                created_lineups = openCreatedLineupsForDate(game_day[1], file_name)
                selected_entries = created_lineups.loc[:selection]
                cash_line_wins, gpp_line_wins,cash_line_losses, gpp_line_losses,top_three, tenth_place, fiftyth_place = calculateWL(selected_entries, 
                                                                                              gpp_line, 
                                                                                              cash_line, 
                                                                                              cash_line_wins, 
                                                                                              gpp_line_wins,
                                                                                              cash_line_losses, 
                                                                                              gpp_line_losses,
                                                                                              top_three,
                                                                                              tenth_place,
                                                                                              fiftyth_place)
            cash_line_win_percent, gpp_line_win_percent, total_win_percent = calculateWinPercentage(cash_line_wins, 
                                                                                                    gpp_line_wins,
                                                                                                    cash_line_losses, 
                                                                                                    gpp_line_losses)
                                                                                                
            full_report.append({'total_win_percent': total_win_percent,
                                'cash_win_percent': cash_line_win_percent,
                                'gpp_win_percent': gpp_line_win_percent,
                                'top_three': top_three,
                                'tenth_place:': tenth_place,
                                'fifthy_place:': fiftyth_place, 
                                'file_name': file_name, 
                                'selection': selection+1})
    return full_report

# %%
x = calculateProfitability()

# %%
x
# Out:
# [{'total_win_percent': 0.4,
#   'cash_win_percent': 0.8,
#   'gpp_win_percent': 0.0,
#   'top_three': 0,
#   'tenth_place:': 0,
#   'fifthy_place:': 0,
#   'file_name': 'RandomlyCreatedLineups',
#   'selection': 1},
#  {'total_win_percent': 0.4,
#   'cash_win_percent': 0.4,
#   'gpp_win_percent': 0.4,
#   'top_three': 0,
#   'tenth_place:': 0,
#   'fifthy_place:': 0,
#   'file_name': 'RandomlyCreatedLineups',
#   'selection': 2},
#  {'total_win_percent': 0.8,
#   'cash_win_percent': 0.8,
#   'gpp_win_percent': 0.8,
#   'top_three': 0,
#   'tenth_place:': 0,
#   'fifthy_place:': 0,
#   'file_name': 'RandomlyCreatedLineups',
#   'selection': 3},
#  {'total_win_percent': 0.7000000000000001,
#   'cash_win_percent': 0.8,
#   'gpp_win_percent': 0.6,
#   'top_three': 0,
#   'tenth_place:': 0,
#   'fifthy_place:': 0,
#   'file_name': 'RandomlyCreatedLineups',
#   'selection': 4},
#  {'total_win_percent': 0.5599999999999999,
#   'cash_win_percent': 0.64,
#   'gpp_win_percent': 0.48,
#   'top_three': 0,
#   'tenth_place:': 0,
#   'fifthy_place:': 0,
#   'file_name': 'RandomlyCreatedLineups',
#   'selection': 5},
#  {'total_win_percent': 0.5333333333333333,
#   'cash_win_percent': 0.6666666666666667,
#   'gpp_win_percent': 0.4,
#   'top_three': 0,
#   'tenth_place:': 0,
#   'fifthy_place:': 0,
#   'file_name': 'RandomlyCreatedLineups',
#   'selection': 6},
#  {'total_win_percent': 0.5714285714285714,
#   'cash_win_percent': 0.6857142857142857,
#   'gpp_win_percent': 0.4571428571428572,
#   'top_three': 0,
#   'tenth_place:': 0,
#   'fifthy_place:': 0,
#   'file_name': 'RandomlyCreatedLineups',
#   'selection': 7},
#  {'total_win_percent': 0.65,
#   'cash_win_percent': 0.8,
#   'gpp_win_percent': 0.5,
#   'top_three': 0,
#   'tenth_place:': 0,
#   'fifthy_place:': 0,
#   'file_name': 'RandomlyCreatedLineups',
#   'selection': 8},
#  {'total_win_percent': 0.6666666666666667,
#   'cash_win_percent': 0.8,
#   'gpp_win_percent': 0.5333333333333333,
#   'top_three': 0,
#   'tenth_place:': 0,
#   'fifthy_place:': 0,
#   'file_name': 'RandomlyCreatedLineups',
#   'selection': 9},
#  {'total_win_percent': 0.76,
#   'cash_win_percent': 0.88,
#   'gpp_win_percent': 0.64,
#   'top_three': 0,
#   'tenth_place:': 0,
#   'fifthy_place:': 0,
#   'file_name': 'RandomlyCreatedLineups',
#   'selection': 10},
#  {'total_win_percent': 0.76,
#   'cash_win_percent': 0.88,
#   'gpp_win_percent': 0.64,
#   'top_three': 0,
#   'tenth_place:': 0,
#   'fifthy_place:': 0,
#   'file_name': 'RandomlyCreatedLineups',
#   'selection': 11},
#  {'total_win_percent': 33.6,
#   'cash_win_percent': 42.4,
#   'gpp_win_percent': 24.8,
#   'top_three': 1,
#   'tenth_place:': 1,
#   'fifthy_place:': 1,
#   'file_name': 'BestCreatedLineups_AvgProj_Baseline',
#   'selection': 1},
#  {'total_win_percent': 31.4,
#   'cash_win_percent': 38.0,
#   'gpp_win_percent': 24.8,
#   'top_three': 2,
#   'tenth_place:': 2,
#   'fifthy_place:': 2,
#   'file_name': 'BestCreatedLineups_AvgProj_Baseline',
#   'selection': 2},
#  {'total_win_percent': 32.266666666666666,
#   'cash_win_percent': 38.666666666666664,
#   'gpp_win_percent': 25.866666666666667,
#   'top_three': 3,
#   'tenth_place:': 3,
#   'fifthy_place:': 3,
#   'file_name': 'BestCreatedLineups_AvgProj_Baseline',
#   'selection': 3},
#  {'total_win_percent': 32.7,
#   'cash_win_percent': 38.6,
#   'gpp_win_percent': 26.8,
#   'top_three': 4,
#   'tenth_place:': 4,
#   'fifthy_place:': 4,
#   'file_name': 'BestCreatedLineups_AvgProj_Baseline',
#   'selection': 4},
#  {'total_win_percent': 31.919999999999998,
#   'cash_win_percent': 37.92,
#   'gpp_win_percent': 25.919999999999998,
#   'top_three': 4,
#   'tenth_place:': 5,
#   'fifthy_place:': 5,
#   'file_name': 'BestCreatedLineups_AvgProj_Baseline',
#   'selection': 5},
#  {'total_win_percent': 31.933333333333337,
#   'cash_win_percent': 37.46666666666666,
#   'gpp_win_percent': 26.400000000000002,
#   'top_three': 5,
#   'tenth_place:': 6,
#   'fifthy_place:': 6,
#   'file_name': 'BestCreatedLineups_AvgProj_Baseline',
#   'selection': 6},
#  {'total_win_percent': 31.771428571428572,
#   'cash_win_percent': 37.48571428571428,
#   'gpp_win_percent': 26.057142857142857,
#   'top_three': 6,
#   'tenth_place:': 7,
#   'fifthy_place:': 7,
#   'file_name': 'BestCreatedLineups_AvgProj_Baseline',
#   'selection': 7},
#  {'total_win_percent': 31.25,
#   'cash_win_percent': 37.0,
#   'gpp_win_percent': 25.5,
#   'top_three': 7,
#   'tenth_place:': 8,
#   'fifthy_place:': 8,
#   'file_name': 'BestCreatedLineups_AvgProj_Baseline',
#   'selection': 8},
#  {'total_win_percent': 30.711111111111112,
#   'cash_win_percent': 36.62222222222222,
#   'gpp_win_percent': 24.8,
#   'top_three': 8,
#   'tenth_place:': 9,
#   'fifthy_place:': 9,
#   'file_name': 'BestCreatedLineups_AvgProj_Baseline',
#   'selection': 9},
#  {'total_win_percent': 30.159999999999997,
#   'cash_win_percent': 36.08,
#   'gpp_win_percent': 24.240000000000002,
#   'top_three': 9,
#   'tenth_place:': 10,
#   'fifthy_place:': 10,
#   'file_name': 'BestCreatedLineups_AvgProj_Baseline',
#   'selection': 10},
#  {'total_win_percent': 29.381818181818183,
#   'cash_win_percent': 35.199999999999996,
#   'gpp_win_percent': 23.563636363636363,
#   'top_three': 10,
#   'tenth_place:': 11,
#   'fifthy_place:': 11,
#   'file_name': 'BestCreatedLineups_AvgProj_Baseline',
#   'selection': 11},
#  {'total_win_percent': 30.4,
#   'cash_win_percent': 36.0,
#   'gpp_win_percent': 24.8,
#   'top_three': 1,
#   'tenth_place:': 1,
#   'fifthy_place:': 1,
#   'file_name': 'BestCreatedLineups_ElasticNet',
#   'selection': 1},
#  {'total_win_percent': 32.6,
#   'cash_win_percent': 38.800000000000004,
#   'gpp_win_percent': 26.400000000000002,
#   'top_three': 2,
#   'tenth_place:': 2,
#   'fifthy_place:': 2,
#   'file_name': 'BestCreatedLineups_ElasticNet',
#   'selection': 2},
#  {'total_win_percent': 29.86666666666667,
#   'cash_win_percent': 36.266666666666666,
#   'gpp_win_percent': 23.466666666666665,
#   'top_three': 3,
#   'tenth_place:': 3,
#   'fifthy_place:': 3,
#   'file_name': 'BestCreatedLineups_ElasticNet',
#   'selection': 3},
#  {'total_win_percent': 30.4,
#   'cash_win_percent': 36.8,
#   'gpp_win_percent': 24.0,
#   'top_three': 4,
#   'tenth_place:': 4,
#   'fifthy_place:': 4,
#   'file_name': 'BestCreatedLineups_ElasticNet',
#   'selection': 4},
#  {'total_win_percent': 30.56,
#   'cash_win_percent': 36.96,
#   'gpp_win_percent': 24.16,
#   'top_three': 5,
#   'tenth_place:': 5,
#   'fifthy_place:': 5,
#   'file_name': 'BestCreatedLineups_ElasticNet',
#   'selection': 5},
#  {'total_win_percent': 30.466666666666665,
#   'cash_win_percent': 36.666666666666664,
#   'gpp_win_percent': 24.266666666666666,
#   'top_three': 6,
#   'tenth_place:': 6,
#   'fifthy_place:': 6,
#   'file_name': 'BestCreatedLineups_ElasticNet',
#   'selection': 6},
#  {'total_win_percent': 30.742857142857144,
#   'cash_win_percent': 37.142857142857146,
#   'gpp_win_percent': 24.342857142857145,
#   'top_three': 7,
#   'tenth_place:': 7,
#   'fifthy_place:': 7,
#   'file_name': 'BestCreatedLineups_ElasticNet',
#   'selection': 7},
#  {'total_win_percent': 30.15,
#   'cash_win_percent': 36.8,
#   'gpp_win_percent': 23.5,
#   'top_three': 8,
#   'tenth_place:': 8,
#   'fifthy_place:': 8,
#   'file_name': 'BestCreatedLineups_ElasticNet',
#   'selection': 8},
#  {'total_win_percent': 29.733333333333334,
#   'cash_win_percent': 36.08888888888889,
#   'gpp_win_percent': 23.377777777777776,
#   'top_three': 9,
#   'tenth_place:': 9,
#   'fifthy_place:': 9,
#   'file_name': 'BestCreatedLineups_ElasticNet',
#   'selection': 9},
#  {'total_win_percent': 28.92,
#   'cash_win_percent': 35.199999999999996,
#   'gpp_win_percent': 22.64,
#   'top_three': 10,
#   'tenth_place:': 10,
#   'fifthy_place:': 10,
#   'file_name': 'BestCreatedLineups_ElasticNet',
#   'selection': 10},
#  {'total_win_percent': 28.836363636363636,
#   'cash_win_percent': 35.054545454545455,
#   'gpp_win_percent': 22.618181818181817,
#   'top_three': 11,
#   'tenth_place:': 11,
#   'fifthy_place:': 12,
#   'file_name': 'BestCreatedLineups_ElasticNet',
#   'selection': 11},
#  {'total_win_percent': 34.4,
#   'cash_win_percent': 40.0,
#   'gpp_win_percent': 28.799999999999997,
#   'top_three': 1,
#   'tenth_place:': 1,
#   'fifthy_place:': 1,
#   'file_name': 'BestCreatedLineups_LinearRegression',
#   'selection': 1},
#  {'total_win_percent': 34.4,
#   'cash_win_percent': 42.0,
#   'gpp_win_percent': 26.8,
#   'top_three': 2,
#   'tenth_place:': 2,
#   'fifthy_place:': 2,
#   'file_name': 'BestCreatedLineups_LinearRegression',
#   'selection': 2},
#  {'total_win_percent': 32.53333333333333,
#   'cash_win_percent': 39.46666666666667,
#   'gpp_win_percent': 25.6,
#   'top_three': 3,
#   'tenth_place:': 3,
#   'fifthy_place:': 3,
#   'file_name': 'BestCreatedLineups_LinearRegression',
#   'selection': 3},
#  {'total_win_percent': 31.900000000000002,
#   'cash_win_percent': 38.800000000000004,
#   'gpp_win_percent': 25.0,
#   'top_three': 4,
#   'tenth_place:': 4,
#   'fifthy_place:': 4,
#   'file_name': 'BestCreatedLineups_LinearRegression',
#   'selection': 4},
#  {'total_win_percent': 30.4,
#   'cash_win_percent': 37.76,
#   'gpp_win_percent': 23.04,
#   'top_three': 5,
#   'tenth_place:': 5,
#   'fifthy_place:': 5,
#   'file_name': 'BestCreatedLineups_LinearRegression',
#   'selection': 5},
#  {'total_win_percent': 30.2,
#   'cash_win_percent': 37.6,
#   'gpp_win_percent': 22.8,
#   'top_three': 6,
#   'tenth_place:': 6,
#   'fifthy_place:': 7,
#   'file_name': 'BestCreatedLineups_LinearRegression',
#   'selection': 6},
#  {'total_win_percent': 30.228571428571428,
#   'cash_win_percent': 37.6,
#   'gpp_win_percent': 22.857142857142858,
#   'top_three': 7,
#   'tenth_place:': 7,
#   'fifthy_place:': 10,
#   'file_name': 'BestCreatedLineups_LinearRegression',
#   'selection': 7},
#  {'total_win_percent': 30.0,
#   'cash_win_percent': 37.4,
#   'gpp_win_percent': 22.6,
#   'top_three': 8,
#   'tenth_place:': 8,
#   'fifthy_place:': 11,
#   'file_name': 'BestCreatedLineups_LinearRegression',
#   'selection': 8},
#  {'total_win_percent': 29.599999999999998,
#   'cash_win_percent': 36.888888888888886,
#   'gpp_win_percent': 22.311111111111114,
#   'top_three': 9,
#   'tenth_place:': 9,
#   'fifthy_place:': 12,
#   'file_name': 'BestCreatedLineups_LinearRegression',
#   'selection': 9},
#  {'total_win_percent': 29.2,
#   'cash_win_percent': 36.16,
#   'gpp_win_percent': 22.24,
#   'top_three': 10,
#   'tenth_place:': 10,
#   'fifthy_place:': 13,
#   'file_name': 'BestCreatedLineups_LinearRegression',
#   'selection': 10},
#  {'total_win_percent': 28.909090909090907,
#   'cash_win_percent': 35.709090909090904,
#   'gpp_win_percent': 22.10909090909091,
#   'top_three': 12,
#   'tenth_place:': 12,
#   'fifthy_place:': 15,
#   'file_name': 'BestCreatedLineups_LinearRegression',
#   'selection': 11},
#  {'total_win_percent': 38.4,
#   'cash_win_percent': 44.800000000000004,
#   'gpp_win_percent': 32.0,
#   'top_three': 1,
#   'tenth_place:': 2,
#   'fifthy_place:': 2,
#   'file_name': 'BestCreatedLineups_LinearRegression_400',
#   'selection': 1},
#  {'total_win_percent': 37.0,
#   'cash_win_percent': 44.0,
#   'gpp_win_percent': 30.0,
#   'top_three': 2,
#   'tenth_place:': 3,
#   'fifthy_place:': 3,
#   'file_name': 'BestCreatedLineups_LinearRegression_400',
#   'selection': 2},
#  {'total_win_percent': 36.13333333333333,
#   'cash_win_percent': 44.266666666666666,
#   'gpp_win_percent': 28.000000000000004,
#   'top_three': 3,
#   'tenth_place:': 4,
#   'fifthy_place:': 4,
#   'file_name': 'BestCreatedLineups_LinearRegression_400',
#   'selection': 3},
#  {'total_win_percent': 35.199999999999996,
#   'cash_win_percent': 42.6,
#   'gpp_win_percent': 27.800000000000004,
#   'top_three': 4,
#   'tenth_place:': 5,
#   'fifthy_place:': 5,
#   'file_name': 'BestCreatedLineups_LinearRegression_400',
#   'selection': 4},
#  {'total_win_percent': 35.120000000000005,
#   'cash_win_percent': 42.559999999999995,
#   'gpp_win_percent': 27.68,
#   'top_three': 5,
#   'tenth_place:': 6,
#   'fifthy_place:': 6,
#   'file_name': 'BestCreatedLineups_LinearRegression_400',
#   'selection': 5},
#  {'total_win_percent': 36.4,
#   'cash_win_percent': 43.46666666666666,
#   'gpp_win_percent': 29.333333333333332,
#   'top_three': 6,
#   'tenth_place:': 7,
#   'fifthy_place:': 8,
#   'file_name': 'BestCreatedLineups_LinearRegression_400',
#   'selection': 6},
#  {'total_win_percent': 36.971428571428575,
#   'cash_win_percent': 43.77142857142857,
#   'gpp_win_percent': 30.17142857142857,
#   'top_three': 7,
#   'tenth_place:': 8,
#   'fifthy_place:': 9,
#   'file_name': 'BestCreatedLineups_LinearRegression_400',
#   'selection': 7},
#  {'total_win_percent': 36.15,
#   'cash_win_percent': 42.9,
#   'gpp_win_percent': 29.4,
#   'top_three': 8,
#   'tenth_place:': 9,
#   'fifthy_place:': 10,
#   'file_name': 'BestCreatedLineups_LinearRegression_400',
#   'selection': 8},
#  {'total_win_percent': 35.77777777777777,
#   'cash_win_percent': 42.31111111111111,
#   'gpp_win_percent': 29.244444444444444,
#   'top_three': 9,
#   'tenth_place:': 10,
#   'fifthy_place:': 11,
#   'file_name': 'BestCreatedLineups_LinearRegression_400',
#   'selection': 9},
#  {'total_win_percent': 35.839999999999996,
#   'cash_win_percent': 42.4,
#   'gpp_win_percent': 29.28,
#   'top_three': 10,
#   'tenth_place:': 11,
#   'fifthy_place:': 12,
#   'file_name': 'BestCreatedLineups_LinearRegression_400',
#   'selection': 10},
#  {'total_win_percent': 35.27272727272727,
#   'cash_win_percent': 41.67272727272727,
#   'gpp_win_percent': 28.87272727272727,
#   'top_three': 11,
#   'tenth_place:': 12,
#   'fifthy_place:': 14,
#   'file_name': 'BestCreatedLineups_LinearRegression_400',
#   'selection': 11},
#  {'total_win_percent': 43.6,
#   'cash_win_percent': 48.8,
#   'gpp_win_percent': 38.4,
#   'top_three': 1,
#   'tenth_place:': 1,
#   'fifthy_place:': 1,
#   'file_name': 'BestCreatedLineups_LinearRegression_800',
#   'selection': 1},
#  {'total_win_percent': 41.6,
#   'cash_win_percent': 48.0,
#   'gpp_win_percent': 35.199999999999996,
#   'top_three': 2,
#   'tenth_place:': 2,
#   'fifthy_place:': 2,
#   'file_name': 'BestCreatedLineups_LinearRegression_800',
#   'selection': 2},
#  {'total_win_percent': 41.46666666666667,
#   'cash_win_percent': 48.0,
#   'gpp_win_percent': 34.93333333333333,
#   'top_three': 3,
#   'tenth_place:': 3,
#   'fifthy_place:': 3,
#   'file_name': 'BestCreatedLineups_LinearRegression_800',
#   'selection': 3},
#  {'total_win_percent': 42.199999999999996,
#   'cash_win_percent': 49.4,
#   'gpp_win_percent': 35.0,
#   'top_three': 4,
#   'tenth_place:': 4,
#   'fifthy_place:': 4,
#   'file_name': 'BestCreatedLineups_LinearRegression_800',
#   'selection': 4},
#  {'total_win_percent': 40.88,
#   'cash_win_percent': 48.16,
#   'gpp_win_percent': 33.6,
#   'top_three': 5,
#   'tenth_place:': 5,
#   'fifthy_place:': 6,
#   'file_name': 'BestCreatedLineups_LinearRegression_800',
#   'selection': 5},
#  {'total_win_percent': 39.93333333333333,
#   'cash_win_percent': 46.93333333333333,
#   'gpp_win_percent': 32.93333333333333,
#   'top_three': 6,
#   'tenth_place:': 6,
#   'fifthy_place:': 7,
#   'file_name': 'BestCreatedLineups_LinearRegression_800',
#   'selection': 6},
#  {'total_win_percent': 39.6,
#   'cash_win_percent': 46.74285714285714,
#   'gpp_win_percent': 32.457142857142856,
#   'top_three': 7,
#   'tenth_place:': 7,
#   'fifthy_place:': 8,
#   'file_name': 'BestCreatedLineups_LinearRegression_800',
#   'selection': 7},
#  {'total_win_percent': 39.15,
#   'cash_win_percent': 45.800000000000004,
#   'gpp_win_percent': 32.5,
#   'top_three': 8,
#   'tenth_place:': 8,
#   'fifthy_place:': 9,
#   'file_name': 'BestCreatedLineups_LinearRegression_800',
#   'selection': 8},
#  {'total_win_percent': 38.84444444444444,
#   'cash_win_percent': 45.77777777777778,
#   'gpp_win_percent': 31.91111111111111,
#   'top_three': 9,
#   'tenth_place:': 9,
#   'fifthy_place:': 11,
#   'file_name': 'BestCreatedLineups_LinearRegression_800',
#   'selection': 9},
#  {'total_win_percent': 38.4,
#   'cash_win_percent': 45.2,
#   'gpp_win_percent': 31.6,
#   'top_three': 10,
#   'tenth_place:': 10,
#   'fifthy_place:': 12,
#   'file_name': 'BestCreatedLineups_LinearRegression_800',
#   'selection': 10},
#  {'total_win_percent': 37.70909090909091,
#   'cash_win_percent': 44.29090909090909,
#   'gpp_win_percent': 31.127272727272725,
#   'top_three': 11,
#   'tenth_place:': 11,
#   'fifthy_place:': 13,
#   'file_name': 'BestCreatedLineups_LinearRegression_800',
#   'selection': 11},
#  {'total_win_percent': 36.8,
#   'cash_win_percent': 42.4,
#   'gpp_win_percent': 31.2,
#   'top_three': 1,
#   'tenth_place:': 1,
#   'fifthy_place:': 1,
#   'file_name': 'BestCreatedLineups',
#   'selection': 1},
#  {'total_win_percent': 37.6,
#   'cash_win_percent': 44.0,
#   'gpp_win_percent': 31.2,
#   'top_three': 2,
#   'tenth_place:': 2,
#   'fifthy_place:': 3,
#   'file_name': 'BestCreatedLineups',
#   'selection': 2},
#  {'total_win_percent': 38.4,
#   'cash_win_percent': 44.266666666666666,
#   'gpp_win_percent': 32.53333333333333,
#   'top_three': 3,
#   'tenth_place:': 3,
#   'fifthy_place:': 5,
#   'file_name': 'BestCreatedLineups',
#   'selection': 3},
#  {'total_win_percent': 39.800000000000004,
#   'cash_win_percent': 46.2,
#   'gpp_win_percent': 33.4,
#   'top_three': 4,
#   'tenth_place:': 5,
#   'fifthy_place:': 7,
#   'file_name': 'BestCreatedLineups',
#   'selection': 4},
#  {'total_win_percent': 39.2,
#   'cash_win_percent': 46.08,
#   'gpp_win_percent': 32.32,
#   'top_three': 5,
#   'tenth_place:': 6,
#   'fifthy_place:': 10,
#   'file_name': 'BestCreatedLineups',
#   'selection': 5},
#  {'total_win_percent': 39.93333333333333,
#   'cash_win_percent': 46.93333333333333,
#   'gpp_win_percent': 32.93333333333333,
#   'top_three': 6,
#   'tenth_place:': 7,
#   'fifthy_place:': 11,
#   'file_name': 'BestCreatedLineups',
#   'selection': 6},
#  {'total_win_percent': 39.885714285714286,
#   'cash_win_percent': 46.85714285714286,
#   'gpp_win_percent': 32.91428571428571,
#   'top_three': 7,
#   'tenth_place:': 8,
#   'fifthy_place:': 13,
#   'file_name': 'BestCreatedLineups',
#   'selection': 7},
#  {'total_win_percent': 39.900000000000006,
#   'cash_win_percent': 46.7,
#   'gpp_win_percent': 33.1,
#   'top_three': 8,
#   'tenth_place:': 9,
#   'fifthy_place:': 15,
#   'file_name': 'BestCreatedLineups',
#   'selection': 8},
#  {'total_win_percent': 38.711111111111116,
#   'cash_win_percent': 45.33333333333333,
#   'gpp_win_percent': 32.08888888888889,
#   'top_three': 9,
#   'tenth_place:': 10,
#   'fifthy_place:': 18,
#   'file_name': 'BestCreatedLineups',
#   'selection': 9},
#  {'total_win_percent': 38.080000000000005,
#   'cash_win_percent': 44.879999999999995,
#   'gpp_win_percent': 31.28,
#   'top_three': 10,
#   'tenth_place:': 11,
#   'fifthy_place:': 19,
#   'file_name': 'BestCreatedLineups',
#   'selection': 10},
#  {'total_win_percent': 37.09090909090909,
#   'cash_win_percent': 44.0,
#   'gpp_win_percent': 30.181818181818183,
#   'top_three': 11,
#   'tenth_place:': 12,
#   'fifthy_place:': 21,
#   'file_name': 'BestCreatedLineups',
#   'selection': 11}]
