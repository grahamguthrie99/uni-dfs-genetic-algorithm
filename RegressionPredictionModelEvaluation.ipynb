# %%
#drop player that is out

# %%
import pandas as pd 
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt

# %%
dates_all = [
    ['2_4', '2020-02-04'],
    ['2_3', '2020-02-03'],
    ['2_2', '2020-02-02'],
    ['2_1', '2020-02-01'],
    ['1_31', '2020-01-31'],
    ['1_30', '2020-01-30'],
    ['1_29', '2020-01-29'],
    ['1_28', '2020-01-28'],
    ['1_27', '2020-01-27'],
    ['1_26', '2020-01-26'],
    ['1_25', '2020-01-25'],
    ['1_24', '2020-01-24'],
    ['1_23', '2020-01-23'],
    ['1_22', '2020-01-22'],
    ['1_20', '2020-01-20'],
    ['1_19', '2020-01-19'],
    ['1_18', '2020-01-18'],
    ['1_17', '2020-01-17'],
    ['1_16', '2020-01-16'],
    ['1_15', '2020-01-15'],
    ['1_14', '2020-01-14'],
    ['1_13', '2020-01-13'],
    ['1_12', '2020-01-12'],
    ['1_11', '2020-01-11'],
    ['1_10', '2020-01-10'],
    ['1_9', '2020-01-09'],
    ['1_8', '2020-01-08'],
    ['1_7', '2020-01-07'],
    ['1_6', '2020-01-06'],
    ['1_5', '2020-01-05'],
    ['1_4', '2020-01-04'],
    ['1_3', '2020-01-03'],
    ['1_2', '2020-01-02'],
    ['1_1', '2020-01-01'],
    ['12_31', '2019-12-31'],
    ['12_30', '2019-12-30'],
    ['12_29', '2019-12-29'],
    ['12_28', '2019-12-28'],
    ['12_27', '2019-12-27'],
    ['12_26', '2019-12-26'],
    ['12_25', '2019-12-25'],
    ['12_23', '2019-12-23'],
    ['12_22', '2019-12-22'],
    ['12_21', '2019-12-21'],
    ['12_20', '2019-12-20'],
    ['12_19', '2019-12-19'],
    ['12_18', '2019-12-18'],
    ['12_17', '2019-12-17'],
    ['12_16', '2019-12-16'],
    ['12_15', '2019-12-15'],
    ['12_14', '2019-12-14'],
    ['12_13', '2019-12-13'],
    ['12_12', '2019-12-12'],
    ['12_11', '2019-12-11'],
    ['12_10', '2019-12-10'],
    ['12_9', '2019-12-09'],
    ['12_8', '2019-12-08'],
    ['12_7', '2019-12-07'],
    ['12_6', '2019-12-06'],
    ['12_5', '2019-12-05'],
    ['12_4', '2019-12-04'],
    ['12_3', '2019-12-03'],
    ['12_2', '2019-12-02'],
    ['12_1', '2019-12-01'],
    ['11_30', '2019-11-30'],
    ['11_29', '2019-11-29'],
    ['11_27', '2019-11-27'],
    ['11_26', '2019-11-26'],
    ['11_25', '2019-11-25'],
    ['11_24', '2019-11-24'],
    ['11_23', '2019-11-23'],
    ['11_22', '2019-11-22'],
    ['11_21', '2019-11-21'],
    ['11_20', '2019-11-20'],
    ['11_19', '2019-11-19'],
    ['11_18', '2019-11-18'],
    ['11_17', '2019-11-17'],
    ['11_16', '2019-11-16'],
    ['11_15', '2019-11-15'],
    ['11_14', '2019-11-14'],
    ['11_13', '2019-11-13'],
    ['11_12', '2019-11-12'],
    ['11_11', '2019-11-11'],
    ['11_10', '2019-11-10'],
    ['11_9', '2019-11-09'],
    ['11_8', '2019-11-08'],
    ['11_7', '2019-11-07'],
    ['11_6', '2019-11-06'],
    ['11_5', '2019-11-05'],
    ['11_4', '2019-11-04'],
    ['11_3', '2019-11-03'],
    ['11_2', '2019-11-02'],
    ['11_1', '2019-11-01'],
    ['10_31', '2019-10-31'],
    ['10_30', '2019-10-30'],
    ['10_29', '2019-10-29'],
    ['10_28', '2019-10-28'],
    ['10_27', '2019-10-27'],
    ['10_26', '2019-10-26'],
    ['10_25', '2019-10-25'],
    ['10_24', '2019-10-24'],
    ['10_23', '2019-10-23'],
    ['10_22', '2019-10-22'],   
]

dates = [
    ['2_3', '2020-02-03'],
 
]

drop_attribs = [
        "game_date",
        'ppg_projection', 
        'value_projection', 
        "position",
        "salary", 
    
        'FantasyFuelValueProj',
        'DFN_ValueProj',
        'Proj Val'
]

# %%
def mergeAllDates():
    file = pd.DataFrame()
    for game_day in dates_all:
        game_date = 'HistoricalData_Merged/{}'.format(game_day[1])
        file = file.append(pd.read_csv(game_date), ignore_index=True)
    return file

def reduceForProjectionAnalysis(file):
    file['FantasyFuelPPGProj'] = file['ppg_projection']
    file['FantasyFuelValueProj'] = file['value_projection']
    file['DFN_PPGProj'] = file['Proj FP']
    file['DFN_ValueProj'] = file['Proj Val']
    file['Avg Proj'] = ((file['DFN_PPGProj']+file['FantasyFuelPPGProj'])/2)
    file['Avg Val'] = ((file['DFN_ValueProj']+file['FantasyFuelValueProj'])/2)
    file.drop(drop_attribs, axis=1, inplace=True)
    file = file[file['injury_status'] != 'O']
    return file

full_df = reduceForProjectionAnalysis(mergeAllDates())

full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13678 entries, 0 to 16564
# Data columns (total 36 columns):
# Player Name           13678 non-null object
# injury_status         656 non-null object
# team                  13678 non-null object
# opp                   13678 non-null object
# spread                13640 non-null float64
# over_under            13640 non-null float64
# implied_team_score    13640 non-null float64
# L5_dvp_rank           13678 non-null int64
# L5_ppg_floor          13650 non-null float64
# L5_ppg_avg            13650 non-null float64
# L5_ppg_max            13650 non-null float64
# Pos                   13678 non-null object
# Salary                13678 non-null int64
# Rest                  13390 non-null float64
# Opp Pace              13678 non-null int64
# Opp DEff              13678 non-null int64
# Opp DvP               13678 non-null object
# L2 FGA                13678 non-null int64
# L5 FGA                13678 non-null int64
# S FGA                 13678 non-null int64
# L2 Min                13678 non-null int64
# L5 Min                13678 non-null int64
# S Min                 13678 non-null int64
# L5 FP                 13678 non-null float64
# S FP                  13678 non-null float64
# Floor FP              13678 non-null float64
# Ceil FP               13678 non-null float64
# Proj Min              13678 non-null float64
# Proj FP               13678 non-null float64
# Actual Min            13678 non-null float64
# Actual FP             13678 non-null float64
# Actual Val            13678 non-null float64
# FantasyFuelPPGProj    13678 non-null float64
# DFN_PPGProj           13678 non-null float64
# Avg Proj              13678 non-null float64
# Avg Val               13678 non-null float64
# dtypes: float64(20), int64(10), object(6)
# memory usage: 3.9+ MB

# %%
def rmse(x,y):
    bench_mse = mean_squared_error(y, x)
    bench_rmse = np.sqrt(bench_mse)
    return bench_rmse


def benchmarks(file):
    bench_proj = full_df['Avg Proj']
    bench_actual = full_df['Actual FP']
    print('FP Proj Error: ',rmse(bench_proj, bench_actual))
    
    bench_val = full_df['Avg Val']
    bench_actual_val = full_df['Actual Val']
    print('FP Val Error: ',rmse(bench_val, bench_actual_val))
    
    bench_min = full_df['Proj Min']
    bench_actual_min = full_df['Actual Min']
    print('FP Min Error: ',rmse(bench_min, bench_actual_min))

##Benchmark
benchmarks(full_df)
# Out:
# FP Proj Error:  9.415489865525222
# FP Val Error:  2.085873636994158
# FP Min Error:  6.082232399188834

# %%
def runLinearRegression(df, needed, label_type):
    train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)
    features = train_set.drop(['Actual FP','Actual Min','Actual Val'], axis=1).copy()
    labels = train_set[label_type].copy()
    if(needed):
        features = encodeFeatures(cleanFeatures(features))
    lin_reg = LinearRegression()
    lin_reg.fit(features, labels)
    lin_scores = cross_val_score(lin_reg, features, labels, scoring='neg_mean_squared_error', cv=10)
    lin_rmse_scores = np.sqrt(-lin_scores)
    display_scores(lin_rmse_scores, label_type)

    
    
def display_scores(scores, label_type):
    print("*", label_type)
    print('Scores:', scores)
    print('Mean:' ,scores.mean())
    print('Std:', scores.std())
    

def cleanFeatures(features): 
    features['L5_ppg_floor'].fillna(0, inplace=True)
    features['L5_ppg_avg'].fillna(0, inplace=True)
    features['L5_ppg_max'].fillna(0, inplace=True)
    features['spread'].fillna(features['spread'].mean(), inplace=True)
    features['over_under'].fillna(features['over_under'].mean(), inplace=True)
    features['implied_team_score'].fillna(features['implied_team_score'].mean(), inplace=True)
    features['Rest'].fillna(features['Rest'].mean(), inplace=True)
    features['injury_status'].fillna('good', inplace=True)
    return features

def encodeFeatures(features):
    nba_player = features['Player Name']
    nba_injury = features['injury_status']
    nba_team = features['team']
    nba_opp = features['opp']
    nba_pos = features['Pos']
    nba_dvp = features['Opp DvP']
    
    nba_player_encoded, nba_player_categories = nba_player.factorize()
    nba_injury_encoded, nba_injury_categories = nba_injury.factorize()
    nba_team_encoded, nba_team_categories = nba_team.factorize()
    nba_opp_encoded, nba_opp_categories = nba_opp.factorize()
    nba_pos_encoded, nba_pos_categories = nba_pos.factorize()
    nba_dvp_encoded, nba_dvp_categories = nba_dvp.factorize()
    
    features['Player Name'] = nba_player_encoded
    features['injury_status'] = nba_injury_encoded
    features['team'] = nba_team_encoded
    features['opp'] = nba_opp_encoded
    features['Pos'] = nba_pos_encoded
    features['Opp DvP'] = nba_dvp_encoded
    return features

# %%
runLinearRegression(full_df, True, 'Actual FP')
# Out:
# * Actual FP
# Scores: [9.2488037  9.21735142 9.32757351 9.36836929 9.01783623 9.51739459
#  9.5646921  9.32350128 9.03630958 9.72439092]
# Mean: 9.334622260238868
# Std: 0.21213929494246822

# %%
runLinearRegression(full_df, True, 'Actual Val')
# Out:
# * Actual Val
# Scores: [2.0551187  2.0862933  2.02785986 2.11688311 1.94444119 2.02746723
#  2.0186347  2.10334435 2.00389689 2.03494633]
# Mean: 2.0418885666616124
# Std: 0.04845708063275971

# %%
runLinearRegression(full_df, True, 'Actual Min')
# Out:
# * Actual Min
# Scores: [5.59654387 5.50348842 5.35746199 5.5985019  5.17920137 5.38623559
#  5.44384765 5.44252312 5.27115316 5.82961251]
# Mean: 5.460856958923335
# Std: 0.17531596668575367

# %%
def normalize(df):
    result = df.copy()
    for feature_name in df.columns:
        max_value = df[feature_name].max()
        min_value = df[feature_name].min()
        result[feature_name] = (df[feature_name] - min_value) / (max_value - min_value)
    return result

def standardize(df):
    result = df.copy()
    for feature_name in df.columns:
        mean_value = df[feature_name].mean()
        std_value = df[feature_name].std()
        result[feature_name] = (df[feature_name] - mean_value) / (std_value)
    return result

# %%
encoded_df = encodeFeatures(cleanFeatures(full_df)).copy()
runLinearRegression(encoded_df, False, 'Actual FP')
# Out:
# * Actual FP
# Scores: [9.23692569 9.22062098 9.32345723 9.35586734 9.01623866 9.52507955
#  9.58158936 9.32502179 9.0407125  9.69250446]
# Mean: 9.331801757121369
# Std: 0.20886047911240554

# %%
encoded_df = encodeFeatures(cleanFeatures(full_df)).copy()

# %%
relevant_df = pd.DataFrame()
#relevant_df['Player Name'] = encoded_df['Player Name']
#relevant_df['team'] = encoded_df['team']
relevant_df['Pos'] = encoded_df['Pos']
relevant_df['Actual FP'] = encoded_df['Actual FP']
relevant_df['Actual Val'] = encoded_df['Actual Val']
relevant_df['Actual Min'] = encoded_df['Actual Min']
#relevant_df['Salary'] = encoded_df['Salary']
relevant_df['Avg Proj'] = encoded_df['Avg Proj']
#relevant_df['Avg Val'] = encoded_df['Avg Val'] 
#relevant_df['Opp DvP'] = encoded_df['Opp DvP']
#relevant_df['Proj Min'] = encoded_df['Proj Min']
#relevant_df['Proj PPM'] = (encoded_df['Avg Proj'] / encoded_df['Proj Min']).round(3)
#relevant_df.replace([np.inf, -np.inf], 0, inplace=True)
#relevant_df['Avg Skewed Min'] = ((encoded_df['L2 Min']+encoded_df['L5 Min']+encoded_df['S Min'])/3)
#relevant_df['Avg L5 PPG'] = ((encoded_df['L5_ppg_floor']+encoded_df['L5_ppg_avg']+encoded_df['L5_ppg_max'])/3)
#relevant_df['Avg Skewed FGA'] = ((encoded_df['L2 FGA']+encoded_df['L5 FGA']+encoded_df['S FGA'])/3)
#relevant_df['Avg Skewed FP'] = ((encoded_df['L5 FP']+encoded_df['S FP']+encoded_df['Ceil FP']+encoded_df['Floor FP']+encoded_df['Avg Proj'])/5)


#relevant_df['Avg Proj Bin'] = pd.cut(relevant_df['Avg Proj'], bins=10, labels=False)
#relevant_df['Avg Value Bin'] = pd.cut(relevant_df['Avg Val'], bins=12, labels=False)
#relevant_df['Avg DvP Bin'] = pd.cut(relevant_df['Opp DvP'], bins=2, labels=False)



#relevant_df= normalize(relevant_df)
#relevant_df= standardize(relevant_df)

# %%
corr_matrix = relevant_df.corr()

# %%
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow0_col0 {
#             background-color:  #b40426;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow0_col1 {
#             background-color:  #3b4cc0;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow0_col2 {
#             background-color:  #3b4cc0;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow0_col3 {
#             background-color:  #3b4cc0;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow0_col4 {
#             background-color:  #3b4cc0;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow1_col0 {
#             background-color:  #3e51c5;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow1_col1 {
#             background-color:  #b40426;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow1_col2 {
#             background-color:  #f29072;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow1_col3 {
#             background-color:  #f29072;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow1_col4 {
#             background-color:  #f08a6c;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow2_col0 {
#             background-color:  #4e68d8;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow2_col1 {
#             background-color:  #f08b6e;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow2_col2 {
#             background-color:  #b40426;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow2_col3 {
#             background-color:  #f1ccb8;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow2_col4 {
#             background-color:  #b1cbfc;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow3_col0 {
#             background-color:  #5673e0;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow3_col1 {
#             background-color:  #ef886b;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow3_col2 {
#             background-color:  #f2c9b4;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow3_col3 {
#             background-color:  #b40426;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow3_col4 {
#             background-color:  #f49a7b;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow4_col0 {
#             background-color:  #3b4cc0;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow4_col1 {
#             background-color:  #f08b6e;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow4_col2 {
#             background-color:  #a1c0ff;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow4_col3 {
#             background-color:  #f6a385;
#         }    #T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow4_col4 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2b" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Pos</th>
#         <th class="col_heading level0 col1" >Actual FP</th>
#         <th class="col_heading level0 col2" >Actual Val</th>
#         <th class="col_heading level0 col3" >Actual Min</th>
#         <th class="col_heading level0 col4" >Avg Proj</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2blevel0_row0" class="row_heading level0 row0" >Pos</th>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow0_col0" class="data row0 col0" >1</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow0_col1" class="data row0 col1" >-0.103368</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow0_col2" class="data row0 col2" >-0.0475083</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow0_col3" class="data row0 col3" >-0.0176188</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow0_col4" class="data row0 col4" >-0.120415</td>
#     </tr>    <tr>
#         <th id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2blevel0_row1" class="row_heading level0 row1" >Actual FP</th>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow1_col0" class="data row1 col0" >-0.103368</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow1_col1" class="data row1 col1" >1</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow1_col2" class="data row1 col2" >0.758913</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow1_col3" class="data row1 col3" >0.768939</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow1_col4" class="data row1 col4" >0.760457</td>
#     </tr>    <tr>
#         <th id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2blevel0_row2" class="row_heading level0 row2" >Actual Val</th>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow2_col0" class="data row2 col0" >-0.0475083</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow2_col1" class="data row2 col1" >0.758913</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow2_col2" class="data row2 col2" >1</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow2_col3" class="data row2 col3" >0.588561</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow2_col4" class="data row2 col4" >0.275504</td>
#     </tr>    <tr>
#         <th id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2blevel0_row3" class="row_heading level0 row3" >Actual Min</th>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow3_col0" class="data row3 col0" >-0.0176188</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow3_col1" class="data row3 col1" >0.768939</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow3_col2" class="data row3 col2" >0.588561</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow3_col3" class="data row3 col3" >1</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow3_col4" class="data row3 col4" >0.718741</td>
#     </tr>    <tr>
#         <th id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2blevel0_row4" class="row_heading level0 row4" >Avg Proj</th>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow4_col0" class="data row4 col0" >-0.120415</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow4_col1" class="data row4 col1" >0.760457</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow4_col2" class="data row4 col2" >0.275504</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow4_col3" class="data row4 col3" >0.718741</td>
#         <td id="T_92bc6f6c_5796_11ea_b96a_88e9fe6d8b2brow4_col4" class="data row4 col4" >1</td>
#     </tr></tbody>
# </table>

# %%
runLinearRegression(relevant_df, False, 'Actual FP')
# Out:
# * Actual FP
# Scores: [9.27303357 9.2655796  9.33800528 9.43148201 9.05360591 9.52645471
#  9.68991302 9.40050597 9.10842053 9.72226017]
# Mean: 9.380926077088777
# Std: 0.210780767302936

# %%
# Out:
# array([-96.79675638,  65.42751986,  41.72607288,  96.85618621,
#         33.22325028])

# %%
# Out:
# <style  type="text/css" >
#     #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow0_col0 {
#             background-color:  #b40426;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow0_col1 {
#             background-color:  #cfdaea;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow0_col2 {
#             background-color:  #3b4cc0;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow0_col3 {
#             background-color:  #3b4cc0;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow0_col4 {
#             background-color:  #3b4cc0;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow0_col5 {
#             background-color:  #6485ec;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow0_col6 {
#             background-color:  #3b4cc0;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow0_col7 {
#             background-color:  #3b4cc0;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow0_col8 {
#             background-color:  #3b4cc0;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow1_col0 {
#             background-color:  #edd1c2;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow1_col1 {
#             background-color:  #b40426;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow1_col2 {
#             background-color:  #7da0f9;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow1_col3 {
#             background-color:  #88abfd;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow1_col4 {
#             background-color:  #85a8fc;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow1_col5 {
#             background-color:  #5673e0;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow1_col6 {
#             background-color:  #7a9df8;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow1_col7 {
#             background-color:  #89acfd;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow1_col8 {
#             background-color:  #6384eb;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow2_col0 {
#             background-color:  #465ecf;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow2_col1 {
#             background-color:  #4055c8;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow2_col2 {
#             background-color:  #b40426;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow2_col3 {
#             background-color:  #ea7b60;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow2_col4 {
#             background-color:  #ee8468;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow2_col5 {
#             background-color:  #445acc;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow2_col6 {
#             background-color:  #f1ccb8;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow2_col7 {
#             background-color:  #f7b89c;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow2_col8 {
#             background-color:  #edd2c3;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow3_col0 {
#             background-color:  #3b4cc0;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow3_col1 {
#             background-color:  #4055c8;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow3_col2 {
#             background-color:  #ec7f63;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow3_col3 {
#             background-color:  #b40426;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow3_col4 {
#             background-color:  #c32e31;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow3_col5 {
#             background-color:  #4055c8;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow3_col6 {
#             background-color:  #f39475;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow3_col7 {
#             background-color:  #ec7f63;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow3_col8 {
#             background-color:  #f7aa8c;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow4_col0 {
#             background-color:  #3e51c5;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow4_col1 {
#             background-color:  #4257c9;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow4_col2 {
#             background-color:  #ef886b;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow4_col3 {
#             background-color:  #c32e31;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow4_col4 {
#             background-color:  #b40426;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow4_col5 {
#             background-color:  #4055c8;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow4_col6 {
#             background-color:  #ebd3c6;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow4_col7 {
#             background-color:  #f29072;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow4_col8 {
#             background-color:  #f5c4ac;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow5_col0 {
#             background-color:  #90b2fe;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow5_col1 {
#             background-color:  #3b4cc0;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow5_col2 {
#             background-color:  #6485ec;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow5_col3 {
#             background-color:  #6c8ff1;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow5_col4 {
#             background-color:  #688aef;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow5_col5 {
#             background-color:  #b40426;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow5_col6 {
#             background-color:  #6687ed;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow5_col7 {
#             background-color:  #7da0f9;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow5_col8 {
#             background-color:  #4358cb;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow6_col0 {
#             background-color:  #4e68d8;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow6_col1 {
#             background-color:  #455cce;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow6_col2 {
#             background-color:  #f2c9b4;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow6_col3 {
#             background-color:  #f18d6f;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow6_col4 {
#             background-color:  #efcebd;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow6_col5 {
#             background-color:  #4e68d8;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow6_col6 {
#             background-color:  #b40426;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow6_col7 {
#             background-color:  #f7b194;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow6_col8 {
#             background-color:  #f6bfa6;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow7_col0 {
#             background-color:  #445acc;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow7_col1 {
#             background-color:  #4a63d3;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow7_col2 {
#             background-color:  #f7b99e;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow7_col3 {
#             background-color:  #eb7d62;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow7_col4 {
#             background-color:  #f18f71;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow7_col5 {
#             background-color:  #5b7ae5;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow7_col6 {
#             background-color:  #f7b497;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow7_col7 {
#             background-color:  #b40426;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow7_col8 {
#             background-color:  #bad0f8;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow8_col0 {
#             background-color:  #5e7de7;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow8_col1 {
#             background-color:  #3e51c5;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow8_col2 {
#             background-color:  #f2cbb7;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow8_col3 {
#             background-color:  #f59d7e;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow8_col4 {
#             bac
