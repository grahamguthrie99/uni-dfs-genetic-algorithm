# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from math import floor

# %%
import pandas as pd
from random import sample

# %%
drop_attribs = [
        "game_date",
        'ppg_projection', 
        'value_projection', 
        'Proj FP', 
        'Proj Min', 
        'Proj Val',
        "position",
        "salary", 
        'DFN_PPGProj',
        'FantasyFuelPPGProj',
        'DFN_ValueProj',
        'FantasyFuelValueProj',
        'L2 Min',
        'L5 Min',
        'S Min',
        
        
]

# %% [markdown]
# ## other drop attribs
# "opp",
# "spread",
# "over_under",
# "implied_team_score",
# "L5_dvp_rank",
# "L5_ppg_floor",
# "L5_ppg_avg",
# "L5_ppg_max",
# "Rest",
# "Opp Pace",
# "Opp DEff",
# "Opp DvP",
# "L2 FGA",
# "L5 FGA",
# "S FGA",
# "L2 Min",
# "L5 Min",
# "S Min",
# "L5 FP",
# "S FP",
# "Floor FP",
# "Ceil FP",

# %%
def reduceForProjectionAnalysis(file):
    file['FantasyFuelPPGProj'] = file['ppg_projection']
    file['FantasyFuelValueProj'] = file['value_projection']
    file['DFN_PPGProj'] = file['Proj FP']
    file['DFN_MinProj'] = file['Proj Min']
    file['DFN_ValueProj'] = file['Proj Val']
    file['Avg Proj'] = (file['DFN_PPGProj']+file['FantasyFuelPPGProj'])/2
    file['Avg Value Proj'] = ((file['DFN_ValueProj']+file['FantasyFuelValueProj'])/2)
    file['Avg Skewed Min'] = ((file['L2 Min']+file['L5 Min']+file['S Min'])/3)
    file['Avg Skewed FGA'] = ((file['L2 FGA']+file['L5 FGA']+file['S FGA'])/3)
    file['Avg Skewed FP'] = ((file['L5 FP']+file['S FP']+file['Ceil FP']+file['Floor FP']+file['Avg Proj'])/5)
    file['Avg L5 PPG'] = ((file['L5_ppg_floor']+file['L5_ppg_avg']+file['L5_ppg_max'])/3)
    
    file['Proj Min Enhanced'] = (file['Avg Proj'] / file['Avg Skewed Min'] ) * file['Proj Min']
    
    file.drop(drop_attribs, axis=1, inplace=True)
    file = file[file['injury_status'] != 'O']
    file = file[file['injury_status'] != 'Q']
    return file

# %% [markdown]
# point_guards = point_guards.sample(frac=0.8, replace=True, random_state=1, weights='Avg Value Proj')
#     shooting_guards = shooting_guards.sample(frac=0.8, replace=True, random_state=1, weights='Avg Value Proj')
#     small_forwards = small_forwards.sample(frac=0.8, replace=True, random_state=1, weights='Avg Value Proj')
#     power_forwards = power_forwards.sample(frac=0.8, replace=True, random_state=1, weights='Avg Value Proj')
#     guards = guards.sample(frac=0.8, replace=True, random_state=1, weights='Avg Value Proj')
#     forwards = forwards.sample(frac=0.8, replace=True, random_state=1, weights='Avg Value Proj')
#     centers = centers.sample(frac=0.8, replace=True, random_state=1, weights='Avg Value Proj')

# %%
##Helper Functions
def verifyLineup(lineup):
    enough_represented_teams = len(set(lineup['team'].tolist()))>=2
    under_salary_cap = lineup['Salary'].sum() <= 50000
    all_unique_players = len(set(lineup['Player Name'].tolist())) == 8
    if enough_represented_teams and under_salary_cap and all_unique_players:
        return True
    else:
        return False
    
def createRandomPopulation(point_guards, shooting_guards, small_forwards, power_forwards, guards, forwards, centers, util, limit):
    counter = 0
    lineups = []
    while(counter<limit):
        lineup = pd.DataFrame()
        lineup = lineup.append(point_guards.sample(n=1))
        lineup = lineup.append(shooting_guards.sample(n=1))
        lineup = lineup.append(small_forwards.sample(n=1))
        lineup = lineup.append(power_forwards.sample(n=1))
        lineup = lineup.append(guards.sample(n=1))
        lineup = lineup.append(forwards.sample(n=1))
        lineup = lineup.append(centers.sample(n=1))
        lineup = lineup.append(util.sample(n=1))
        if(verifyLineup(lineup)):
            lineups.append(lineup)
            counter = counter + 1
    return lineups


def mate(_parents):
    parents = pd.concat(sample(_parents, 10))
    point_guards = parents.loc[parents['Pos'].str.contains("PG")]
    shooting_guards = parents.loc[parents['Pos'].str.contains("SG")]
    small_forwards = parents.loc[parents['Pos'].str.contains("SF")]
    power_forwards = parents.loc[parents['Pos'].str.contains("PF")]
    guards = parents.loc[parents['Pos'].str.contains("G")]
    forwards = parents.loc[parents['Pos'].str.contains("F")]
    centers = parents.loc[parents['Pos'].str.contains("C")]
    util = parents
    
    children = []
    while(len(children) < 10):
        child_lineup = _parents[0].append(_parents[1])
        while(not verifyLineup(child_lineup)):
            child_lineup = pd.DataFrame()
            child_lineup = child_lineup.append(point_guards.sample(n=1))
            child_lineup = child_lineup.append(shooting_guards.sample(n=1))
            child_lineup = child_lineup.append(small_forwards.sample(n=1))
            child_lineup = child_lineup.append(power_forwards.sample(n=1))
            child_lineup = child_lineup.append(guards.sample(n=1))
            child_lineup = child_lineup.append(forwards.sample(n=1))
            child_lineup = child_lineup.append(centers.sample(n=1))
            child_lineup = child_lineup.append(util.sample(n=1))
        children.append(child_lineup)
    return children

def sortFitestBasedOnProjection(population): 
    population.sort(key=projectedPointSum, reverse=True)
    population = eliminateDuplicates(population)
    return population 

def projectedPointSum(lineup):
    return lineup['Avg Proj Stan'].sum() + lineup['DFN_MinProj Stan'].sum() + lineup['Proj Min Enhanced Stan'].sum() + lineup['Avg Skewed FP'].sum()

def eliminateDuplicates(population):
    unique_lineups = set()
    unique_population = []
    for lineup in population:
        lineup_set = set()
        for player in lineup['Player Name'].tolist():
            lineup_set.add(player)
            
        if(not lineup_set.issubset(unique_lineups)):  
            unique_population.append(lineup)
            unique_lineups = unique_lineups.union(lineup_set)
    return unique_population

# %%
def performSelection(population):
    selected_population = population[:1]
    selected_population.extend(sample(population[1:5], 3))
    selected_population.extend(sample(population[5:10], 2))
    selected_population.extend(sample(population, 10))
    return selected_population


def performCrossover(population):
    children = []
    parents = population
    children = mate(parents) 
    return children
        

def createNextGeneration(old_population):
    selected_population = performSelection(old_population)
    children = performCrossover(selected_population)
    new_generation = old_population[:len(old_population)-10]
    new_generation.extend(children)
    return new_generation

# %% [markdown]
# def findConvergence(population, total_players):
#     unique_players = pd.concat(population)
#     unique_players.drop_duplicates(subset ="Player Name", keep = 'first', inplace = True)
#     percentage_of_unique_players = len(unique_players['Player Name'].value_counts().keys().tolist()) / total_players
#     projection_value = unique_players['Avg Proj'].mean()
#     val_value = unique_players['Avg Value Proj'].mean()
#     minutes_value = unique_players['DFN_MinProj'].mean()
#     drop_level = unique_players['Proj FP'].mean() - unique['Proj FP'].std()
#     projection_value = unique_players['Avg Proj'].mean()
#     file[file.apply(lambda  x: x['Actual FP'] > drop_level, axis=1)]
#     print("Unique Player Percentage: ", percentage_of_unique_players )
#     print("Proj Val: ", projection_value )
#     print("Val: ", val_value )
#     print("Min Val: ", minutes_value )
#     print("XXX")
#     unique_player_threshold = percentage_of_unique_players < .55
#     projection_threshold = 24 < projection_value < 32
#     value_threshold = 4.4 < val_value < 5.4
#     minutes_threshold = 25 < minutes_value < 31
#     return  unique_player_threshold and projection_threshold and value_threshold and minutes_threshold

# %%
def findConvergence(population, total_players):
    represented_players = pd.concat(population)
    percentage_of_unique_players = len(set(represented_players['Player Name'].value_counts().keys().tolist())) / total_players
    projection_value = represented_players['Avg Proj'].mean()
    val_value = represented_players['Avg Value Proj'].mean()
    minutes_value = represented_players['DFN_MinProj'].mean()
    projection_value = represented_players['Avg Proj'].mean()
    
    print("Unique Player Percentage: ", percentage_of_unique_players )
    print("Proj Val: ", projection_value )
    print("Val: ", val_value )
    print("Min Val: ", minutes_value )
    print("XXX")
    unique_player_threshold = percentage_of_unique_players < .53
    projection_threshold = 28.6 < projection_value < 34
    value_threshold = 4.6 < val_value < 5.6
    minutes_threshold = 27 < minutes_value < 32
    return  unique_player_threshold and projection_threshold and value_threshold and minutes_threshold

# %%
def standardize(df):
    result = df.copy()
    categories = ['Avg Proj', 'DFN_MinProj', 'Proj Min Enhanced', 'Avg Skewed FP']
    for feature_name in categories:
        mean_value = df[feature_name].mean()
        std_value = df[feature_name].std()
        result[feature_name + ' Stan'] = ((df[feature_name] - mean_value) / (std_value))
    return result

def geneticAlgorithmForHistorialBestLineups(file):
    #file = normalize(file)
    file = standardize(file)
    total_players = len(file['Player Name'].tolist())
    population_size = 30
    point_guards = file.loc[file['Pos'].str.contains("PG")]
    shooting_guards = file.loc[file['Pos'].str.contains("SG")]
    small_forwards = file.loc[file['Pos'].str.contains("SF")]
    power_forwards = file.loc[file['Pos'].str.contains("PF")]
    guards = file.loc[file['Pos'].str.contains("G")]
    forwards = file.loc[file['Pos'].str.contains("F")]
    centers = file.loc[file['Pos'].str.contains("C")]
    util = file
    population = createRandomPopulation(point_guards, shooting_guards, 
                                               small_forwards, power_forwards, 
                                               guards, forwards, centers, util, population_size)  
   
    converged = False
    while(not converged):
        currentPopulation = sortFitestBasedOnProjection(population)
        converged = findConvergence(population, total_players)
        if(not converged):
            population = createNextGeneration(currentPopulation)
            population.extend(createRandomPopulation(point_guards, shooting_guards, 
                                               small_forwards, power_forwards, 
                                               guards, forwards, centers, util, 30 - len(population)))
       
    print("*****************")
    return sortFitestBasedOnProjection(population)

# %%
dates_all = [
    ['2_4', '2020-02-04'],
    ['2_3', '2020-02-03'],
    ['2_2', '2020-02-02'],
    ['2_1', '2020-02-01'],
    ['1_31', '2020-01-31'],
    ['1_30', '2020-01-30'],
    ['1_29', '2020-01-29'],
    ['1_28', '2020-01-28'],
    ['1_27', '2020-01-27'],
    ['1_26', '2020-01-26'],
    ['1_25', '2020-01-25'],
    ['1_24', '2020-01-24'],
    ['1_23', '2020-01-23'],
    ['1_22', '2020-01-22'],
    ['1_20', '2020-01-20'],
    ['1_19', '2020-01-19'],
    ['1_18', '2020-01-18'],
    ['1_17', '2020-01-17'],
    ['1_16', '2020-01-16'],
    ['1_15', '2020-01-15'],
    ['1_14', '2020-01-14'],
    ['1_13', '2020-01-13'],
    ['1_12', '2020-01-12'],
    ['1_11', '2020-01-11'],
    ['1_10', '2020-01-10'],
    ['1_9', '2020-01-09'],
    ['1_8', '2020-01-08'],
    ['1_7', '2020-01-07'],
    ['1_6', '2020-01-06'],
    ['1_5', '2020-01-05'],
    ['1_4', '2020-01-04'],
    ['1_3', '2020-01-03'],
    ['1_2', '2020-01-02'],
    ['1_1', '2020-01-01'],
    ['12_31', '2019-12-31'],
    ['12_30', '2019-12-30'],
    ['12_29', '2019-12-29'],
    ['12_28', '2019-12-28'],
    ['12_27', '2019-12-27'],
    ['12_26', '2019-12-26'],
    ['12_25', '2019-12-25'],
    ['12_23', '2019-12-23'],
    ['12_22', '2019-12-22'],
    ['12_21', '2019-12-21'],
    ['12_20', '2019-12-20'],
    ['12_19', '2019-12-19'],
    ['12_18', '2019-12-18'],
    ['12_17', '2019-12-17'],
    ['12_16', '2019-12-16'],
    ['12_15', '2019-12-15'],
    ['12_14', '2019-12-14'],
    ['12_13', '2019-12-13'],
    ['12_12', '2019-12-12'],
    ['12_11', '2019-12-11'],
    ['12_10', '2019-12-10'],
    ['12_9', '2019-12-09'],
    ['12_8', '2019-12-08'],
    ['12_7', '2019-12-07'],
    ['12_6', '2019-12-06'],
    ['12_5', '2019-12-05'],
    ['12_4', '2019-12-04'],
    ['12_3', '2019-12-03'],
    ['12_2', '2019-12-02'],
    ['12_1', '2019-12-01'],
    ['11_30', '2019-11-30'],
    ['11_29', '2019-11-29'],
    ['11_27', '2019-11-27'],
    ['11_26', '2019-11-26'],
    ['11_25', '2019-11-25'],
    ['11_24', '2019-11-24'],
    ['11_23', '2019-11-23'],
    ['11_22', '2019-11-22'],
    ['11_21', '2019-11-21'],
    ['11_20', '2019-11-20'],
    ['11_19', '2019-11-19'],
    ['11_18', '2019-11-18'],
    ['11_17', '2019-11-17'],
    ['11_16', '2019-11-16'],
    ['11_15', '2019-11-15'],
    ['11_14', '2019-11-14'],
    ['11_13', '2019-11-13'],
    ['11_12', '2019-11-12'],
    ['11_11', '2019-11-11'],
    ['11_10', '2019-11-10'],
    ['11_9', '2019-11-09'],
    ['11_8', '2019-11-08'],
    ['11_7', '2019-11-07'],
    ['11_6', '2019-11-06'],
    ['11_5', '2019-11-05'],
    ['11_4', '2019-11-04'],
    ['11_3', '2019-11-03'],
    ['11_2', '2019-11-02'],
    ['11_1', '2019-11-01'],
    ['10_31', '2019-10-31'],
    ['10_30', '2019-10-30'],
    ['10_29', '2019-10-29'],
    ['10_28', '2019-10-28'],
    ['10_27', '2019-10-27'],
    ['10_26', '2019-10-26'],
    ['10_25', '2019-10-25'],
    ['10_24', '2019-10-24'],
    ['10_23', '2019-10-23'],
    ['10_22', '2019-10-22'],   
]

dates = [
    ['2_4', '2020-02-04'],
    #['2_3', '2020-02-03'],
    #['2_2', '2020-02-02'],
    #['2_1', '2020-02-01'],
    #['1_31', '2020-01-31'],
    #['1_30', '2020-01-30'],
    #['1_29', '2020-01-29'],
    #['1_28', '2020-01-28'],
    #['1_27', '2020-01-27'],
    #['1_26', '2020-01-26'],
    
   
]

def resetIndicies(file):
    for lineup in file:
        lineup.reset_index(drop=True, inplace=True)
    return file

def saveBestLineups_toCSV(file, date):
    key = np.arange(len(file))
    file_name = 'BestCreatedLineups/{}'.format(date)
    new_file = pd.concat(file, keys=key, names=['Lineup Num'])
    new_file.to_csv(file_name)

def createBestLineups():
    for game_day in dates:
        file_name = 'HistoricalData_Merged/{}'.format(game_day[1])
        cleaned_file = reduceForProjectionAnalysis(pd.read_csv(file_name))
        best_population = geneticAlgorithmForHistorialBestLineups(cleaned_file)
        saveBestLineups_toCSV(resetIndicies(best_population), game_day[1])

# %%
createBestLineups()
# Out:
# Unique Player Percentage:  0.9324324324324325
# Proj Val:  23.9725
# Val:  4.510020833333334
# Min Val:  23.695833333333333
# XXX
# Unique Player Percentage:  0.9459459459459459
# Proj Val:  24.074166666666663
# Val:  4.4915
# Min Val:  23.677083333333332
# XXX
# Unique Player Percentage:  0.8783783783783784
# Proj Val:  25.846041666666665
# Val:  4.6494375
# Min Val:  25.104166666666668
# XXX
# Unique Player Percentage:  0.8378378378378378
# Proj Val:  25.84375
# Val:  4.652958333333333
# Min Val:  25.370833333333334
# XXX
# Unique Player Percentage:  0.8243243243243243
# Proj Val:  25.484375
# Val:  4.663395833333333
# Min Val:  25.064583333333335
# XXX
# Unique Player Percentage:  0.8513513513513513
# Proj Val:  27.883750000000003
# Val:  4.860125
# Min Val:  27.404166666666665
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  27.827083333333334
# Val:  4.813416666666667
# Min Val:  27.027083333333334
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  28.368749999999995
# Val:  4.897687500000001
# Min Val:  27.852083333333333
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  29.051875000000003
# Val:  4.9230625
# Min Val:  27.964583333333334
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  28.857291666666665
# Val:  4.948520833333333
# Min Val:  28.029166666666665
# XXX
# Unique Player Percentage:  0.6891891891891891
# Proj Val:  29.196666666666662
# Val:  4.9895000000000005
# Min Val:  28.035416666666666
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  28.936666666666664
# Val:  4.963083333333333
# Min Val:  28.208333333333332
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  28.282916666666665
# Val:  4.879999999999999
# Min Val:  27.489583333333332
# XXX
# Unique Player Percentage:  0.6351351351351351
# Proj Val:  29.314999999999994
# Val:  4.998791666666666
# Min Val:  28.164583333333333
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  26.835833333333333
# Val:  4.702395833333332
# Min Val:  26.00625
# XXX
# Unique Player Percentage:  0.6891891891891891
# Proj Val:  27.345833333333335
# Val:  4.852999999999999
# Min Val:  26.829166666666666
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  28.121875
# Val:  4.870354166666666
# Min Val:  27.445833333333333
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  29.952291666666664
# Val:  5.0569999999999995
# Min Val:  28.597916666666666
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  28.52854166666667
# Val:  4.926583333333332
# Min Val:  27.754166666666666
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  28.759166666666662
# Val:  4.919833333333333
# Min Val:  27.43125
# XXX
# Unique Player Percentage:  0.7162162162162162
# Proj Val:  28.794791666666665
# Val:  4.910270833333333
# Min Val:  27.41875
# XXX
# Unique Player Percentage:  0.7162162162162162
# Proj Val:  29.467916666666664
# Val:  4.972708333333333
# Min Val:  28.110416666666666
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  29.444791666666664
# Val:  4.9947291666666676
# Min Val:  27.829166666666666
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  29.273124999999997
# Val:  4.934520833333333
# Min Val:  27.354166666666668
# XXX
# Unique Player Percentage:  0.6756756756756757
# Proj Val:  30.101249999999997
# Val:  5.1029374999999995
# Min Val:  28.727083333333333
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  28.758541666666662
# Val:  4.967645833333334
# Min Val:  27.577083333333334
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  30.09125
# Val:  5.03125
# Min Val:  28.366666666666667
# XXX
# Unique Player Percentage:  0.6756756756756757
# Proj Val:  30.296875
# Val:  5.023270833333333
# Min Val:  28.475
# XXX
# Unique Player Percentage:  0.8243243243243243
# Proj Val:  28.582083333333333
# Val:  4.875958333333333
# Min Val:  27.33125
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  28.394375
# Val:  4.9331875
# Min Val:  27.147916666666667
# XXX
# Unique Player Percentage:  0.6351351351351351
# Proj Val:  30.639166666666664
# Val:  5.074645833333333
# Min Val:  28.80625
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  28.223958333333332
# Val:  4.925041666666667
# Min Val:  27.24375
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  29.020000000000003
# Val:  4.9576875000000005
# Min Val:  27.889583333333334
# XXX
# Unique Player Percentage:  0.6756756756756757
# Proj Val:  30.43791666666667
# Val:  5.137854166666667
# Min Val:  29.175
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  30.103958333333335
# Val:  5.108083333333334
# Min Val:  28.791666666666668
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  29.267083333333336
# Val:  4.98725
# Min Val:  28.38125
# XXX
# Unique Player Percentage:  0.7837837837837838
# Proj Val:  28.963749999999997
# Val:  4.9628749999999995
# Min Val:  27.835416666666667
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  30.356666666666666
# Val:  5.063479166666667
# Min Val:  28.99375
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  29.534791666666667
# Val:  5.115312499999999
# Min Val:  28.777083333333334
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  28.95333333333333
# Val:  5.0131041666666665
# Min Val:  28.254166666666666
# XXX
# Unique Player Percentage:  0.5945945945945946
# Proj Val:  31.099166666666665
# Val:  5.2065
# Min Val:  29.88125
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  27.682291666666668
# Val:  5.002583333333333
# Min Val:  27.65
# XXX
# Unique Player Percentage:  0.8108108108108109
# Proj Val:  28.114583333333332
# Val:  4.9791041666666676
# Min Val:  27.866666666666667
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  30.20604166666666
# Val:  5.1031875
# Min Val:  28.933333333333334
# XXX
# Unique Player Percentage:  0.6891891891891891
# Proj Val:  29.928958333333334
# Val:  5.096104166666667
# Min Val:  28.739583333333332
# XXX
# Unique Player Percentage:  0.8108108108108109
# Proj Val:  29.0825
# Val:  5.014395833333333
# Min Val:  27.933333333333334
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  30.359166666666663
# Val:  5.077895833333333
# Min Val:  28.291666666666668
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  29.910833333333336
# Val:  5.1195625
# Min Val:  28.722916666666666
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  29.78416666666667
# Val:  5.228875
# Min Val:  29.083333333333332
# XXX
# Unique Player Percentage:  0.8243243243243243
# Proj Val:  27.91395833333333
# Val:  4.9941249999999995
# Min Val:  27.185416666666665
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  30.243541666666665
# Val:  5.132520833333333
# Min Val:  28.616666666666667
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  29.95875
# Val:  5.063520833333333
# Min Val:  28.508333333333333
# XXX
# Unique Player Percentage:  0.7837837837837838
# Proj Val:  29.83791666666667
# Val:  5.124916666666667
# Min Val:  28.608333333333334
# XXX
# Unique Player Percentage:  0.7162162162162162
# Proj Val:  30.179166666666667
# Val:  5.1859166666666665
# Min Val:  29.097916666666666
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  29.984374999999996
# Val:  5.146916666666667
# Min Val:  29.202083333333334
# XXX
# Unique Player Percentage:  0.7162162162162162
# Proj Val:  30.299374999999998
# Val:  5.1731875
# Min Val:  29.339583333333334
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  30.023124999999997
# Val:  5.158708333333334
# Min Val:  28.716666666666665
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  30.004583333333333
# Val:  5.126062500000001
# Min Val:  28.416666666666668
# XXX
# Unique Player Percentage:  0.7837837837837838
# Proj Val:  29.461666666666662
# Val:  5.078541666666666
# Min Val:  27.985416666666666
# XXX
# Unique Player Percentage:  0.8378378378378378
# Proj Val:  30.093124999999997
# Val:  5.0806666666666676
# Min Val:  28.402083333333334
# XXX
# Unique Player Percentage:  0.6621621621621622
# Proj Val:  30.641666666666662
# Val:  5.197958333333333
# Min Val:  29.439583333333335
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  29.922291666666663
# Val:  5.0866875
# Min Val:  28.708333333333332
# XXX
# Unique Player Percentage:  0.6621621621621622
# Proj Val:  30.935624999999998
# Val:  5.193395833333333
# Min Val:  29.354166666666668
# XXX
# Unique Player Percentage:  0.8108108108108109
# Proj Val:  28.62645833333333
# Val:  5.073145833333332
# Min Val:  28.420833333333334
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  30.079999999999995
# Val:  5.195583333333333
# Min Val:  29.116666666666667
# XXX
# Unique Player Percentage:  0.8243243243243243
# Proj Val:  29.368541666666662
# Val:  5.123645833333334
# Min Val:  28.502083333333335
# XXX
# Unique Player Percentage:  0.6486486486486487
# Proj Val:  30.63583333333333
# Val:  5.2865416666666665
# Min Val:  29.764583333333334
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  28.69416666666666
# Val:  5.071208333333334
# Min Val:  27.875
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  30.014791666666664
# Val:  5.127458333333334
# Min Val:  28.560416666666665
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  29.572708333333328
# Val:  5.054854166666667
# Min Val:  28.383333333333333
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  29.28625
# Val:  5.026041666666667
# Min Val:  28.416666666666668
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  29.157499999999995
# Val:  5.0925416666666665
# Min Val:  28.472916666666666
# XXX
# Unique Player Percentage:  0.8648648648648649
# Proj Val:  28.398541666666667
# Val:  4.958270833333333
# Min Val:  27.6
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  29.192291666666666
# Val:  5.021229166666668
# Min Val:  28.164583333333333
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  29.927083333333332
# Val:  5.1151875
# Min Val:  28.764583333333334
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  29.822916666666668
# Val:  5.144895833333334
# Min Val:  28.889583333333334
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  27.86520833333333
# Val:  4.991916666666667
# Min Val:  26.991666666666667
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  29.92791666666667
# Val:  5.2108125
# Min Val:  28.947916666666668
# XXX
# Unique Player Percentage:  0.8243243243243243
# Proj Val:  28.583541666666665
# Val:  5.020166666666666
# Min Val:  27.79375
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  29.581249999999997
# Val:  5.019395833333333
# Min Val:  28.227083333333333
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  29.418125
# Val:  5.11475
# Min Val:  28.28125
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  30.033749999999998
# Val:  5.048895833333334
# Min Val:  28.185416666666665
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  29.675416666666663
# Val:  5.158229166666667
# Min Val:  28.34375
# XXX
# Unique Player Percentage:  0.6621621621621622
# Proj Val:  30.970833333333328
# Val:  5.261354166666667
# Min Val:  29.547916666666666
# XXX
# Unique Player Percentage:  0.8108108108108109
# Proj Val:  27.2975
# Val:  4.8838333333333335
# Min Val:  26.375
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  29.11083333333333
# Val:  5.118020833333333
# Min Val:  28.475
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  28.551249999999996
# Val:  5.064583333333333
# Min Val:  28.022916666666667
# XXX
# Unique Player Percentage:  0.8378378378378378
# Proj Val:  27.669166666666666
# Val:  4.972479166666667
# Min Val:  27.270833333333332
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  29.723124999999996
# Val:  5.141333333333334
# Min Val:  28.6125
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  28.009375
# Val:  5.085854166666667
# Min Val:  27.485416666666666
# XXX
# Unique Player Percentage:  0.8648648648648649
# Proj Val:  28.09395833333333
# Val:  4.944333333333333
# Min Val:  26.935416666666665
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  29.16875
# Val:  4.977479166666667
# Min Val:  27.697916666666668
# XXX
# Unique Player Percentage:  0.6891891891891891
# Proj Val:  30.59958333333333
# Val:  5.188291666666667
# Min Val:  29.033333333333335
# XXX
# Unique Player Percentage:  0.7162162162162162
# Proj Val:  29.287499999999998
# Val:  5.023854166666666
# Min Val:  28.129166666666666
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  29.54770833333333
# Val:  5.08225
# Min Val:  28.422916666666666
# XXX
# Unique Player Percentage:  0.7162162162162162
# Proj Val:  29.896875
# Val:  5.146604166666666
# Min Val:  28.866666666666667
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  29.178749999999997
# Val:  5.210416666666666
# Min Val:  29.01875
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  29.422291666666663
# Val:  5.1310625
# Min Val:  28.695833333333333
# XXX
# Unique Player Percentage:  0.6756756756756757
# Proj Val:  30.536041666666666
# Val:  5.277333333333333
# Min Val:  29.79375
# XXX
# Unique Player Percentage:  0.8108108108108109
# Proj Val:  28.402499999999996
# Val:  5.005729166666667
# Min Val:  27.425
# XXX
# Unique Player Percentage:  0.8513513513513513
# Proj Val:  27.337291666666665
# Val:  4.920958333333333
# Min Val:  27.002083333333335
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  29.64020833333333
# Val:  5.029812500000001
# Min Val:  28.247916666666665
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  29.793333333333333
# Val:  5.244125
# Min Val:  29.3375
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  28.920624999999998
# Val:  5.097479166666667
# Min Val:  28.589583333333334
# XXX
# Unique Player Percentage:  0.8243243243243243
# Proj Val:  28.28458333333333
# Val:  5.031291666666666
# Min Val:  27.785416666666666
# XXX
# Unique Player Percentage:  0.6891891891891891
# Proj Val:  30.385416666666664
# Val:  5.235541666666667
# Min Val:  29.54375
# XXX
# Unique Player Percentage:  0.8108108108108109
# Proj Val:  27.64395833333333
# Val:  4.935999999999999
# Min Val:  27.279166666666665
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  27.845416666666665
# Val:  4.924625000000001
# Min Val:  27.235416666666666
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  28.735833333333336
# Val:  5.112687500000001
# Min Val:  28.247916666666665
# XXX
# Unique Player Percentage:  0.7837837837837838
# Proj Val:  29.37895833333333
# Val:  5.1198749999999995
# Min Val:  28.3125
# XXX
# Unique Player Percentage:  0.6891891891891891
# Proj Val:  30.38083333333333
# Val:  5.2508125
# Min Val:  29.33125
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  30.313958333333336
# Val:  5.1609791666666665
# Min Val:  28.933333333333334
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  30.220208333333332
# Val:  5.1789375
# Min Val:  28.7875
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  29.063541666666662
# Val:  5.079979166666666
# Min Val:  28.166666666666668
# XXX
# Unique Player Percentage:  0.8513513513513513
# Proj Val:  26.623958333333334
# Val:  4.812895833333333
# Min Val:  26.395833333333332
# XXX
# Unique Player Percentage:  0.6891891891891891
# Proj Val:  28.933541666666663
# Val:  5.081604166666667
# Min Val:  28.008333333333333
# XXX
# Unique Player Percentage:  0.6891891891891891
# Proj Val:  30.048333333333332
# Val:  5.112333333333334
# Min Val:  28.95
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  28.890416666666663
# Val:  4.906000000000001
# Min Val:  27.610416666666666
# XXX
# Unique Player Percentage:  0.8108108108108109
# Proj Val:  28.221874999999997
# Val:  5.038145833333333
# Min Val:  27.966666666666665
# XXX
# Unique Player Percentage:  0.6756756756756757
# Proj Val:  30.273124999999997
# Val:  5.1978541666666676
# Min Val:  29.354166666666668
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  29.423333333333332
# Val:  5.125875
# Min Val:  28.839583333333334
# XXX
# Unique Player Percentage:  0.8243243243243243
# Proj Val:  27.975416666666664
# Val:  5.014854166666667
# Min Val:  27.614583333333332
# XXX
# Unique Player Percentage:  0.7162162162162162
# Proj Val:  28.927916666666665
# Val:  5.051020833333333
# Min Val:  28.204166666666666
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  29.854999999999997
# Val:  5.095645833333333
# Min Val:  28.929166666666667
# XXX
# Unique Player Percentage:  0.9054054054054054
# Proj Val:  28.3375
# Val:  4.935458333333333
# Min Val:  27.214583333333334
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  29.397916666666667
# Val:  5.018791666666666
# Min Val:  28.147916666666667
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  29.518124999999998
# Val:  4.960104166666667
# Min Val:  28.104166666666668
# XXX
# Unique Player Percentage:  0.6621621621621622
# Proj Val:  30.888125
# Val:  5.2590625
# Min Val:  29.702083333333334
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  28.671249999999997
# Val:  5.050375
# Min Val:  28.097916666666666
# XXX
# Unique Player Percentage:  0.7162162162162162
# Proj Val:  29.389999999999997
# Val:  5.122583333333334
# Min Val:  28.875
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  28.928749999999997
# Val:  5.005729166666667
# Min Val:  27.789583333333333
# XXX
# Unique Player Percentage:  0.7162162162162162
# Proj Val:  29.561666666666664
# Val:  5.074812499999999
# Min Val:  28.720833333333335
# XXX
# Unique Player Percentage:  0.6486486486486487
# Proj Val:  30.345208333333332
# Val:  5.127291666666666
# Min Val:  29.264583333333334
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  29.15083333333333
# Val:  4.9747916666666665
# Min Val:  27.70625
# XXX
# Unique Player Percentage:  0.7837837837837838
# Proj Val:  28.95958333333333
# Val:  4.938833333333334
# Min Val:  27.25
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  30.967916666666664
# Val:  5.159520833333334
# Min Val:  29.266666666666666
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  30.698749999999997
# Val:  5.198541666666666
# Min Val:  29.197916666666668
# XXX
# Unique Player Percentage:  0.7837837837837838
# Proj Val:  29.57333333333333
# Val:  5.1461250000000005
# Min Val:  28.679166666666667
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  29.007083333333338
# Val:  5.132270833333333
# Min Val:  28.547916666666666
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  29.238541666666666
# Val:  5.0723125
# Min Val:  28.472916666666666
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  29.0875
# Val:  5.056166666666667
# Min Val:  28.433333333333334
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  29.44708333333333
# Val:  5.023520833333333
# Min Val:  28.335416666666667
# XXX
# Unique Player Percentage:  0.6891891891891891
# Proj Val:  29.29958333333333
# Val:  5.036625
# Min Val:  28.245833333333334
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  29.515625
# Val:  5.052708333333333
# Min Val:  28.027083333333334
# XXX
# Unique Player Percentage:  0.6621621621621622
# Proj Val:  30.955208333333335
# Val:  5.169625
# Min Val:  29.45
# XXX
# Unique Player Percentage:  0.7162162162162162
# Proj Val:  29.805
# Val:  5.141187499999999
# Min Val:  29.029166666666665
# XXX
# Unique Player Percentage:  0.8108108108108109
# Proj Val:  28.076041666666665
# Val:  4.916416666666667
# Min Val:  27.072916666666668
# XXX
# Unique Player Percentage:  0.6486486486486487
# Proj Val:  29.48395833333333
# Val:  5.019875
# Min Val:  28.297916666666666
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  29.300416666666663
# Val:  4.9879375
# Min Val:  28.154166666666665
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  29.757291666666667
# Val:  5.121104166666667
# Min Val:  29.05
# XXX
# Unique Player Percentage:  0.6756756756756757
# Proj Val:  30.9725
# Val:  5.1967083333333335
# Min Val:  29.627083333333335
# XXX
# Unique Player Percentage:  0.6891891891891891
# Proj Val:  29.71291666666666
# Val:  5.101895833333333
# Min Val:  28.975
# XXX
# Unique Player Percentage:  0.7162162162162162
# Proj Val:  28.596249999999998
# Val:  5.1070625
# Min Val:  28.75
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  30.073958333333334
# Val:  5.137229166666667
# Min Val:  28.98125
# XXX
# Unique Player Percentage:  0.6621621621621622
# Proj Val:  29.50270833333333
# Val:  5.112854166666667
# Min Val:  28.602083333333333
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  29.650208333333335
# Val:  5.0798958333333335
# Min Val:  28.75
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  29.194374999999997
# Val:  5.069583333333332
# Min Val:  28.747916666666665
# XXX
# Unique Player Percentage:  0.6216216216216216
# Proj Val:  30.519583333333333
# Val:  5.230791666666667
# Min Val:  29.952083333333334
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  29.29083333333333
# Val:  5.171354166666666
# Min Val:  28.789583333333333
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  28.297708333333333
# Val:  5.0794999999999995
# Min Val:  27.783333333333335
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  30.548333333333336
# Val:  5.152541666666666
# Min Val:  29.029166666666665
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  29.35333333333333
# Val:  5.087666666666666
# Min Val:  28.71875
# XXX
# Unique Player Percentage:  0.6621621621621622
# Proj Val:  30.274583333333332
# Val:  5.1576875
# Min Val:  28.908333333333335
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  29.123749999999998
# Val:  5.1730625
# Min Val:  28.766666666666666
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  28.384999999999998
# Val:  4.939458333333333
# Min Val:  27.4625
# XXX
# Unique Player Percentage:  0.7837837837837838
# Proj Val:  27.99458333333333
# Val:  4.958458333333334
# Min Val:  27.545833333333334
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  28.542708333333334
# Val:  5.001833333333334
# Min Val:  28.039583333333333
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  29.671041666666664
# Val:  5.1023125
# Min Val:  28.647916666666667
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  29.363541666666666
# Val:  5.0849375
# Min Val:  28.441666666666666
# XXX
# Unique Player Percentage:  0.7162162162162162
# Proj Val:  29.695416666666667
# Val:  5.110083333333334
# Min Val:  28.895833333333332
# XXX
# Unique Player Percentage:  0.8513513513513513
# Proj Val:  28.531875
# Val:  4.891166666666666
# Min Val:  27.439583333333335
# XXX
# Unique Player Percentage:  0.6081081081081081
# Proj Val:  31.06541666666666
# Val:  5.242416666666666
# Min Val:  30.164583333333333
# XXX
# Unique Player Percentage:  0.7162162162162162
# Proj Val:  30.214583333333334
# Val:  5.1581875
# Min Val:  29.30625
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  27.594583333333336
# Val:  4.929020833333333
# Min Val:  27.395833333333332
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  29.69083333333333
# Val:  5.099875000000001
# Min Val:  28.922916666666666
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  30.536458333333332
# Val:  5.167333333333333
# Min Val:  29.6375
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  30.084375
# Val:  5.184604166666667
# Min Val:  29.21875
# XXX
# Unique Player Percentage:  0.6621621621621622
# Proj Val:  30.626041666666666
# Val:  5.237687500000001
# Min Val:  29.827083333333334
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  29.529999999999994
# Val:  5.2163125
# Min Val:  28.741666666666667
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  29.378541666666663
# Val:  5.0569375
# Min Val:  28.139583333333334
# XXX
# Unique Player Percentage:  0.6621621621621622
# Proj Val:  29.090208333333333
# Val:  5.0134791666666665
# Min Val:  27.908333333333335
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  28.87895833333333
# Val:  5.066395833333333
# Min Val:  28.258333333333333
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  30.125625
# Val:  5.197145833333334
# Min Val:  28.972916666666666
# XXX
# Unique Player Percentage:  0.6621621621621622
# Proj Val:  30.88479166666667
# Val:  5.208958333333333
# Min Val:  29.454166666666666
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  30.030625
# Val:  5.178333333333333
# Min Val:  29.141666666666666
# XXX
# Unique Player Percentage:  0.6621621621621622
# Proj Val:  30.565208333333327
# Val:  5.2896875
# Min Val:  29.683333333333334
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  28.16208333333333
# Val:  5.002
# Min Val:  27.860416666666666
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  28.905208333333334
# Val:  4.996583333333333
# Min Val:  27.595833333333335
# XXX
# Unique Player Percentage:  0.6621621621621622
# Proj Val:  31.042291666666664
# Val:  5.222666666666667
# Min Val:  29.45
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  30.450416666666666
# Val:  5.154020833333333
# Min Val:  29.18125
# XXX
# Unique Player Percentage:  0.7162162162162162
# Proj Val:  29.465625
# Val:  5.100729166666666
# Min Val:  28.49375
# XXX
# Unique Player Percentage:  0.8108108108108109
# Proj Val:  28.223958333333332
# Val:  5.033625000000001
# Min Val:  27.94375
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  29.672708333333333
# Val:  5.106729166666667
# Min Val:  28.689583333333335
# XXX
# Unique Player Percentage:  0.6351351351351351
# Proj Val:  30.854375
# Val:  5.30275
# Min Val:  29.870833333333334
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  28.624374999999997
# Val:  4.987729166666666
# Min Val:  27.466666666666665
# XXX
# Unique Player Percentage:  0.6081081081081081
# Proj Val:  31.034375
# Val:  5.263916666666666
# Min Val:  29.889583333333334
# XXX
# Unique Player Percentage:  0.6756756756756757
# Proj Val:  30.077916666666667
# Val:  5.225791666666667
# Min Val:  28.947916666666668
# XXX
# Unique Player Percentage:  0.6891891891891891
# Proj Val:  29.465833333333332
# Val:  5.1537083333333324
# Min Val:  28.579166666666666
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  29.975624999999997
# Val:  5.140812499999999
# Min Val:  28.229166666666668
# XXX
# Unique Player Percentage:  0.5945945945945946
# Proj Val:  31.180625
# Val:  5.298541666666667
# Min Val:  29.804166666666667
# XXX
# Unique Player Percentage:  0.6891891891891891
# Proj Val:  31.26645833333333
# Val:  5.349645833333333
# Min Val:  29.975
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  29.157083333333336
# Val:  5.013270833333333
# Min Val:  28.097916666666666
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  30.035624999999996
# Val:  5.231458333333333
# Min Val:  29.510416666666668
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  30.391041666666663
# Val:  5.242312500000001
# Min Val:  29.422916666666666
# XXX
# Unique Player Percentage:  0.6486486486486487
# Proj Val:  30.134375
# Val:  5.1634375
# Min Val:  28.9375
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  29.6425
# Val:  5.135291666666666
# Min Val:  28.4375
# XXX
# Unique Player Percentage:  0.6891891891891891
# Proj Val:  30.794374999999995
# Val:  5.2718541666666665
# Min Val:  29.695833333333333
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  29.82583333333333
# Val:  5.1890625
# Min Val:  28.914583333333333
# XXX
# Unique Player Percentage:  0.6621621621621622
# Proj Val:  31.010416666666668
# Val:  5.235166666666667
# Min Val:  29.6
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  30.870208333333327
# Val:  5.2044999999999995
# Min Val:  29.252083333333335
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  30.067083333333336
# Val:  5.113729166666667
# Min Val:  28.954166666666666
# XXX
# Unique Player Percentage:  0.6486486486486487
# Proj Val:  30.708541666666665
# Val:  5.192895833333334
# Min Val:  29.541666666666668
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  30.325208333333332
# Val:  5.178458333333333
# Min Val:  29.247916666666665
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  30.296875
# Val:  5.115166666666666
# Min Val:  28.716666666666665
# XXX
# Unique Player Percentage:  0.6351351351351351
# Proj Val:  31.179374999999997
# Val:  5.276604166666666
# Min Val:  30.102083333333333
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  29.379374999999996
# Val:  5.122833333333333
# Min Val:  28.26875
# XXX
# Unique Player Percentage:  0.7162162162162162
# Proj Val:  29.372708333333332
# Val:  5.14125
# Min Val:  28.329166666666666
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  30.160416666666666
# Val:  5.25975
# Min Val:  29.470833333333335
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  29.723749999999995
# Val:  5.142458333333334
# Min Val:  28.695833333333333
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  30.388541666666665
# Val:  5.201499999999999
# Min Val:  29.120833333333334
# XXX
# Unique Player Percentage:  0.8108108108108109
# Proj Val:  29.358124999999998
# Val:  5.167395833333334
# Min Val:  28.197916666666668
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  30.568749999999998
# Val:  5.187583333333333
# Min Val:  28.56875
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  30.804999999999996
# Val:  5.278645833333333
# Min Val:  29.447916666666668
# XXX
# Unique Player Percentage:  0.6891891891891891
# Proj Val:  30.296458333333337
# Val:  5.207145833333334
# Min Val:  28.7625
# XXX
# Unique Player Percentage:  0.8243243243243243
# Proj Val:  29.373541666666664
# Val:  5.144937499999999
# Min Val:  28.31875
# XXX
# Unique Player Percentage:  0.8243243243243243
# Proj Val:  29.20354166666667
# Val:  5.1205625
# Min Val:  28.379166666666666
# XXX
# Unique Player Percentage:  0.6621621621621622
# Proj Val:  30.650624999999998
# Val:  5.262666666666666
# Min Val:  29.166666666666668
# XXX
# Unique Player Percentage:  0.6756756756756757
# Proj Val:  29.98145833333333
# Val:  5.156562500000001
# Min Val:  28.408333333333335
# XXX
# Unique Player Percentage:  0.6486486486486487
# Proj Val:  31.163541666666667
# Val:  5.2923124999999995
# Min Val:  29.347916666666666
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  30.35895833333333
# Val:  5.146729166666666
# Min Val:  28.764583333333334
# XXX
# Unique Player Percentage:  0.6756756756756757
# Proj Val:  30.505
# Val:  5.238874999999999
# Min Val:  28.985416666666666
# XXX
# Unique Player Percentage:  0.8243243243243243
# Proj Val:  27.11208333333333
# Val:  4.8823541666666666
# Min Val:  26.01875
# XXX
# Unique Player Percentage:  0.6216216216216216
# Proj Val:  30.656458333333333
# Val:  5.238729166666666
# Min Val:  28.835416666666667
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  30.359166666666667
# Val:  5.206333333333333
# Min Val:  28.91875
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  29.386458333333334
# Val:  5.085083333333333
# Min Val:  27.608333333333334
# XXX
# Unique Player Percentage:  0.5405405405405406
# Proj Val:  31.47833333333333
# Val:  5.253208333333333
# Min Val:  29.289583333333333
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  29.102083333333333
# Val:  5.166229166666667
# Min Val:  28.114583333333332
# XXX
# Unique Player Percentage:  0.6351351351351351
# Proj Val:  30.80645833333333
# Val:  5.262895833333333
# Min Val:  29.172916666666666
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  29.495416666666664
# Val:  5.157791666666667
# Min Val:  28.25
# XXX
# Unique Player Percentage:  0.7837837837837838
# Proj Val:  29.00083333333333
# Val:  5.030500000000001
# Min Val:  27.677083333333332
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  29.887916666666666
# Val:  5.140645833333334
# Min Val:  28.45
# XXX
# Unique Player Percentage:  0.6756756756756757
# Proj Val:  29.154791666666664
# Val:  5.123770833333333
# Min Val:  27.770833333333332
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  29.354166666666668
# Val:  5.179812500000001
# Min Val:  28.427083333333332
# XXX
# Unique Player Percentage:  0.7162162162162162
# Proj Val:  29.427499999999995
# Val:  5.147895833333333
# Min Val:  28.264583333333334
# XXX
# Unique Player Percentage:  0.6081081081081081
# Proj Val:  30.79708333333333
# Val:  5.2529375
# Min Val:  29.408333333333335
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  30.029583333333335
# Val:  5.185520833333333
# Min Val:  29.002083333333335
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  29.824791666666663
# Val:  5.122145833333334
# Min Val:  28.614583333333332
# XXX
# Unique Player Percentage:  0.6756756756756757
# Proj Val:  30.45916666666666
# Val:  5.226395833333333
# Min Val:  29.004166666666666
# XXX
# Unique Player Percentage:  0.7837837837837838
# Proj Val:  30.06145833333333
# Val:  5.171333333333334
# Min Val:  28.597916666666666
# XXX
# Unique Player Percentage:  0.8378378378378378
# Proj Val:  29.24
# Val:  5.026937500000001
# Min Val:  27.722916666666666
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  29.27895833333333
# Val:  5.065479166666667
# Min Val:  27.452083333333334
# XXX
# Unique Player Percentage:  0.7432432432432432
# Proj Val:  29.453125
# Val:  5.121291666666666
# Min Val:  28.152083333333334
# XXX
# Unique Player Percentage:  0.6486486486486487
# Proj Val:  29.74833333333333
# Val:  5.058333333333334
# Min Val:  28.020833333333332
# XXX
# Unique Player Percentage:  0.6891891891891891
# Proj Val:  29.844166666666663
# Val:  5.1081666666666665
# Min Val:  28.1375
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  29.550833333333333
# Val:  5.165520833333334
# Min Val:  28.608333333333334
# XXX
# Unique Player Percentage:  0.6621621621621622
# Proj Val:  31.05270833333333
# Val:  5.274916666666667
# Min Val:  29.64375
# XXX
# Unique Player Percentage:  0.8108108108108109
# Proj Val:  29.316458333333333
# Val:  5.076062500000001
# Min Val:  28.152083333333334
# XXX
# Unique Player Percentage:  0.7162162162162162
# Proj Val:  31.398333333333326
# Val:  5.225875
# Min Val:  29.4875
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  30.367916666666662
# Val:  5.223145833333333
# Min Val:  28.829166666666666
# XXX
# Unique Player Percentage:  0.6891891891891891
# Proj Val:  30.117291666666667
# Val:  5.257479166666667
# Min Val:  28.989583333333332
# XXX
# Unique Player Percentage:  0.6756756756756757
# Proj Val:  30.621041666666663
# Val:  5.232375
# Min Val:  29.204166666666666
# XXX
# Unique Player Percentage:  0.6486486486486487
# Proj Val:  31.372916666666665
# Val:  5.319354166666668
# Min Val:  30.079166666666666
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  29.856666666666666
# Val:  5.164416666666667
# Min Val:  28.254166666666666
# XXX
# Unique Player Percentage:  0.6891891891891891
# Proj Val:  30.092708333333334
# Val:  5.1719791666666675
# Min Val:  28.716666666666665
# XXX
# Unique Player Percentage:  0.7702702702702703
# Proj Val:  30.023125
# Val:  5.103041666666667
# Min Val:  28.589583333333334
# XXX
# Unique Player Percentage:  0.7297297297297297
# Proj Val:  30.107708333333335
# Val:  5.0946875
# Min Val:  28.3875
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  30.908124999999995
# Val:  5.182166666666668
# Min Val:  29.314583333333335
# XXX
# Unique Player Percentage:  0.6756756756756757
# Proj Val:  30.006249999999998
# Val:  5.165333333333334
# Min Val:  28.841666666666665
# XXX
# Unique Player Percentage:  0.7972972972972973
# Proj Val:  28.375
# Val:  5.000375000000001
# Min Val:  27.370833333333334
# XXX
# Unique Player Percentage:  0.7162162162162162
# Proj Val:  29.351666666666667
# Val:  5.1245625
# Min Val:  28.316666666666666
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  30.13
# Val:  5.222708333333333
# Min Val:  29.208333333333332
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  30.463333333333328
# Val:  5.245145833333334
# Min Val:  29.36875
# XXX
# Unique Player Percentage:  0.6351351351351351
# Proj Val:  31.2625
# Val:  5.2361875
# Min Val:  29.854166666666668
# XXX
# Unique Player Percentage:  0.7567567567567568
# Proj Val:  30.819374999999997
# Val:  5.154562500000001
# Min Val:  29.3375
# XXX
# Unique Player Percentage:  0.6351351351351351
# Proj Val:  32.01291666666667
# Val:  5.327895833333333
# Min Val:  30.4
# XXX
# Unique Player Percentage:  0.8243243243243243
# Proj Val:  27.611041666666665
# Val:  4.967770833333333
# Min Val:  26.833333333333332
# XXX
# Unique Player Percentage:  0.7027027027027027
# Proj Val:  29.892708333333328
# Val:  5.189291666666667
# Min Val:  28.970833333333335
# XXX
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-152-126ca2855f3e> in <module>
# ----> 1 createBestLineups()
#
# <ipython-input-151-275f8bf4f407> in createBestLineups()
#     135         file_name = 'HistoricalData_Merged/{}'.format(game_day[1])
#     136         cleaned_file = reduceForProjectionAnalysis(pd.read_csv(file_name))
# --> 137         best_population = geneticAlgorithmForHistorialBestLineups(cleaned_file)
#     138         saveBestLineups_toCSV(resetIndicies(best_population), game_day[1])
#     139
#
# <ipython-input-150-32ca1387c8a0> in geneticAlgorithmForHistorialBestLineups(file)
#      30         converged = findConvergence(population, total_players)
#      31         if(not converged):
# ---> 32             population = createNextGeneration(currentPopulation)
#      33             population.extend(createRandomPopulation(point_guards, shooting_guards,
#      34                                                small_forwards, power_forwards,
#
# <ipython-input-144-2db3b5c50c12> in createNextGeneration(old_population)
#      16 def createNextGeneration(old_population):
#      17     selected_population = performSelection(old_population)
# ---> 18     children = performCrossover(selected_population)
#      19     new_generation = old_population[:len(old_population)-10]
#      20     new_generation.extend(children)
#
# <ipython-input-144-2db3b5c50c12> in performCrossover(population)
#      10     children = []
#      11     parents = population
# ---> 12     children = mate(parents)
#      13     return children
#      14
#
# <ipython-input-143-4ff03cc66e02> in mate(_parents)
#      50             child_lineup = child_lineup.append(guards.sample(n=1))
#      51             child_lineup = child_lineup.append(forwards.sample(n=1))
# ---> 52             child_lineup = child_lineup.append(centers.sample(n=1))
#      53             child_lineup = child_lineup.append(util.sample(n=1))
#      54         children.append(child_lineup)
#
# ~/Dev/gsquared/ml/DFS/env/lib/python3.7/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7136             ignore_index=ignore_index,
#    7137             verify_integrity=verify_integrity,
# -> 7138             sort=sort,
#    7139         )
#    7140
#
# ~/Dev/gsquared/ml/DFS/env/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     256     )
#     257
# --> 258     return op.get_result()
#     259
#     260
#
# ~/Dev/gsquared/ml/DFS/env/lib/python3.7/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     471
#     472             new_data = concatenate_block_managers(
# --> 473                 mgrs_indexers, self.new_axes, concat_axis=self.axis, copy=self.copy
#     474             )
#     475             if not self.copy:
#
# ~/Dev/gsquared/ml/DFS/env/lib/python3.7/site-packages/pandas/core/internals/managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2052         else:
#    2053             b = make_block(
# -> 2054                 concatenate_join_units(join_units, concat_axis, copy=copy),
#    2055                 placement=placement,
#    2056             )
#
# ~/Dev/gsquared/ml/DFS/env/lib/python3.7/site-packages/pandas/core/internals/concat.py in concatenate_join_units(join_units, concat_axis, copy)
#     247         raise AssertionError("Concatenating join units along axis0")
#     248
# --> 249     empty_dtype, upcasted_na = get_empty_dtype_and_na(join_units)
#     250
#     251     to_concat = [
#
# KeyboardInterrupt:

# %%
def normalize(df):
    result = df.copy()
    categories = ['Avg Proj', 'DFN_MinProj', 'Proj Min Enhanced', ]
    for category in categories:
        max_value = df[category].max()
        min_value = df[category].min()
        result[category + ' Norm'] = ((df[category] - min_value) / (max_value - min_value))
    return result
