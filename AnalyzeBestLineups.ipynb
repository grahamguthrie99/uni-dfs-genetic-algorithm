# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from math import floor

# %%
def openBestLineupsForDate():
    file_name = 'BestLineups/2020-01-24'
    file = pd.read_csv(file_name)
    return file

df = openBestLineupsForDate()

# %%
df.head()
# Out:
#    Unnamed: 0  index     Player Name team    Pos  Salary  Actual Min  \
# 0           0     31    Kemba Walker  BOS     PG    7500        36.3
# 1           1     83   Derrick White   SA  PG/SG    4900        28.3
# 2           2    127  Doug McDermott  IND  SF/PF    3600        23.8
# 3           3     46     T.J. Warren  IND  SF/PF    6000        35.2
# 4           4     98       Josh Hart   NO  SG/SF    4000        27.6
#
#    Actual FP  Actual Val  FantasyFuelPPGProj  FantasyFuelValueProj  \
# 0       60.5         8.1                35.8                  4.77
# 1       39.5         8.1                23.8                  4.85
# 2       32.5         9.0                17.5                  4.86
# 3       53.3         8.9                29.5                  4.92
# 4       41.8        10.4                20.0                  5.00
#
#    DFN_PPGProj  DFN_MinProj  DFN_ValueProj
# 0         42.7         34.5            5.7
# 1         24.7         26.0            5.0
# ...
