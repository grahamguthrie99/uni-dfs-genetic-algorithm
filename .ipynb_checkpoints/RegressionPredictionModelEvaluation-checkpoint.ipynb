# %%
#drop player that is out

# %%
import pandas as pd 
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
dates = [
    ['2_4', '2020-02-04'],
    ['2_3', '2020-02-03'],
    ['2_2', '2020-02-02'],
    ['2_1', '2020-02-01'],
    ['1_31', '2020-01-31'],
    ['1_30', '2020-01-30'],
    ['1_29', '2020-01-29'],
    ['1_28', '2020-01-28'],
    ['1_27', '2020-01-27'],
    ['1_26', '2020-01-26'],
    ['1_25', '2020-01-25'],
    ['1_24', '2020-01-24'],
    ['1_23', '2020-01-23'],
    ['1_22', '2020-01-22'],
    ['1_20', '2020-01-20'],
    ['1_19', '2020-01-19'],
    ['1_18', '2020-01-18'],
    ['1_17', '2020-01-17'],
    ['1_16', '2020-01-16'],
    ['1_15', '2020-01-15'],
    ['1_14', '2020-01-14'],
    ['1_13', '2020-01-13'],
    ['1_12', '2020-01-12'],
    ['1_11', '2020-01-11'],
    ['1_10', '2020-01-10'],
    ['1_9', '2020-01-09'],
    ['1_8', '2020-01-08'],
    ['1_7', '2020-01-07'],
    ['1_6', '2020-01-06'],
    ['1_5', '2020-01-05'],
    ['1_4', '2020-01-04'],
    ['1_3', '2020-01-03'],
    ['1_2', '2020-01-02'],
    ['1_1', '2020-01-01'],
    ['12_31', '2019-12-31'],
    ['12_30', '2019-12-30'],
    ['12_29', '2019-12-29'],
    ['12_28', '2019-12-28'],
    ['12_27', '2019-12-27'],
    ['12_26', '2019-12-26'],
    ['12_25', '2019-12-25'],
    ['12_23', '2019-12-23'],
    ['12_22', '2019-12-22'],
    ['12_21', '2019-12-21'],
    ['12_20', '2019-12-20'],
    ['12_19', '2019-12-19'],
    ['12_18', '2019-12-18'],
    ['12_17', '2019-12-17'],
    ['12_16', '2019-12-16'],
    ['12_15', '2019-12-15'],
    ['12_14', '2019-12-14'],
    ['12_13', '2019-12-13'],
    ['12_12', '2019-12-12'],
    ['12_11', '2019-12-11'],
    ['12_10', '2019-12-10'],
    ['12_9', '2019-12-09'],
    ['12_8', '2019-12-08'],
    ['12_7', '2019-12-07'],
    ['12_6', '2019-12-06'],
    ['12_5', '2019-12-05'],
    ['12_4', '2019-12-04'],
    ['12_3', '2019-12-03'],
    ['12_2', '2019-12-02'],
    ['12_1', '2019-12-01'],
    ['11_30', '2019-11-30'],
    ['11_29', '2019-11-29'],
    ['11_27', '2019-11-27'],
    ['11_26', '2019-11-26'],
    ['11_25', '2019-11-25'],
    ['11_24', '2019-11-24'],
    ['11_23', '2019-11-23'],
    ['11_22', '2019-11-22'],
    ['11_21', '2019-11-21'],
    ['11_20', '2019-11-20'],
    ['11_19', '2019-11-19'],
    ['11_18', '2019-11-18'],
    ['11_17', '2019-11-17'],
    ['11_16', '2019-11-16'],
    ['11_15', '2019-11-15'],
    ['11_14', '2019-11-14'],
    ['11_13', '2019-11-13'],
    ['11_12', '2019-11-12'],
    ['11_11', '2019-11-11'],
    ['11_10', '2019-11-10'],
    ['11_9', '2019-11-09'],
    ['11_8', '2019-11-08'],
    ['11_7', '2019-11-07'],
    ['11_6', '2019-11-06'],
    ['11_5', '2019-11-05'],
    ['11_4', '2019-11-04'],
    ['11_3', '2019-11-03'],
    ['11_2', '2019-11-02'],
    ['11_1', '2019-11-01'],
    ['10_31', '2019-10-31'],
    ['10_30', '2019-10-30'],
    ['10_29', '2019-10-29'],
    ['10_28', '2019-10-28'],
    ['10_27', '2019-10-27'],
    ['10_26', '2019-10-26'],
    ['10_25', '2019-10-25'],
    ['10_24', '2019-10-24'],
    ['10_23', '2019-10-23'],
    ['10_22', '2019-10-22'],   
]

drop_attribs = [
        "game_date",
        'ppg_projection', 
        'value_projection', 
        'Proj FP', 
        'Proj Min', 
        'Proj Val',
        "position",
        "salary", 
        "Actual Min",
        "Actual Val",
]

# %%
def mergeAllDates():
    file = pd.DataFrame()
    for game_day in dates:
        game_date = 'HistoricalData_Merged/{}'.format(game_day[1])
        file = file.append(pd.read_csv(game_date), ignore_index=True)
    return file

def reduceForProjectionAnalysis(file):
    file['FantasyFuelPPGProj'] = file['ppg_projection']
    file['FantasyFuelValueProj'] = file['value_projection']
    file['DFN_PPGProj'] = file['Proj FP']
    file['DFN_MinProj'] = file['Proj Min']
    file['DFN_ValueProj'] = file['Proj Val']
    file.drop(drop_attribs, axis=1, inplace=True)
    return file

full_df = reduceForProjectionAnalysis(mergeAllDates())
full_df['Avg Proj'] = ((full_df['DFN_PPGProj']+full_df['FantasyFuelPPGProj'])/2)
full_df = full_df[full_df['injury_status'] != 'O']

# %%
##Benchmark
bench_proj = full_df['Avg Proj']
bench_actual = full_df['Actual FP']
bench_mse = mean_squared_error(bench_actual, bench_proj)
bench_rmse = np.sqrt(bench_mse)
bench_rmse
# Out:
# 9.415489865525222

# %%
def runLinearRegression(df, needed):
    train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)
    features = train_set.drop('Actual FP', axis=1).copy()
    labels = train_set['Actual FP'].copy()
    if(needed):
        features = encodeFeatures(cleanFeatures(features))
    lin_reg = LinearRegression()
    lin_reg.fit(features, labels)
    lin_scores = cross_val_score(lin_reg, features, labels, scoring='neg_mean_squared_error', cv=10)
    lin_rmse_scores = np.sqrt(-lin_scores)
    display_scores(lin_rmse_scores)
    
    
def display_scores(scores):
    print('Scores:', scores)
    print('Mean:' ,scores.mean())
    print('Std:', scores.std())
    
def cleanFeatures(features): 
    features['L5_ppg_floor'].fillna(0, inplace=True)
    features['L5_ppg_avg'].fillna(0, inplace=True)
    features['L5_ppg_max'].fillna(0, inplace=True)
    features['spread'].fillna(features['spread'].mean(), inplace=True)
    features['over_under'].fillna(features['over_under'].mean(), inplace=True)
    features['implied_team_score'].fillna(features['implied_team_score'].mean(), inplace=True)
    features['Rest'].fillna(features['Rest'].mean(), inplace=True)
    features['injury_status'].fillna('good', inplace=True)
    return features

def encodeFeatures(features):
    nba_player = features['Player Name']
    nba_injury = features['injury_status']
    nba_team = features['team']
    nba_opp = features['opp']
    nba_pos = features['Pos']
    nba_dvp = features['Opp DvP']
    
    nba_player_encoded, nba_player_categories = nba_player.factorize()
    nba_injury_encoded, nba_injury_categories = nba_injury.factorize()
    nba_team_encoded, nba_team_categories = nba_team.factorize()
    nba_opp_encoded, nba_opp_categories = nba_opp.factorize()
    nba_pos_encoded, nba_pos_categories = nba_pos.factorize()
    nba_dvp_encoded, nba_dvp_categories = nba_dvp.factorize()
    
    features['Player Name'] = nba_player_encoded
    features['injury_status'] = nba_injury_encoded
    features['team'] = nba_team_encoded
    features['opp'] = nba_opp_encoded
    features['Pos'] = nba_pos_encoded
    features['Opp DvP'] = nba_dvp_encoded
    return features

# %%
runLinearRegression(full_df, True)
# Out:
# Scores: [9.25124932 9.21735741 9.3271101  9.36834104 9.01846497 9.51871664
#  9.56517567 9.32644991 9.03626017 9.72332018]
# Mean: 9.33524454056773
# Std: 0.21191164438103977

# %%
encoded_df = encodeFeatures(cleanFeatures(full_df)).copy()

relevant_df = pd.DataFrame()
relevant_df['Player Name'] = encoded_df['Player Name']
relevant_df['team'] = encoded_df['team']
relevant_df['Actual FP'] = encoded_df['Actual FP']
relevant_df['Avg Proj'] = encoded_df['Avg Proj']
relevant_df['Salary'] = encoded_df['Salary']
relevant_df['Pos'] = encoded_df['Pos']
relevant_df['Avg Value Proj'] = ((encoded_df['DFN_ValueProj']+encoded_df['FantasyFuelValueProj'])/2)
relevant_df['Avg Skewed Min'] = ((encoded_df['L2 Min']+encoded_df['L5 Min']+encoded_df['S Min'])/3)
relevant_df['FPP Per Min'] = ((encoded_df['Avg Proj']/relevant_df['Avg Skewed Min']))
relevant_df['FPP Per Min'].fillna(0, inplace=True)

#relevant_df['Avg Skewed FGA'] = ((encoded_df['L2 FGA']+encoded_df['L5 FGA']+encoded_df['S FGA'])/3)
#relevant_df['Avg Skewed FP'] = ((encoded_df['L5 FP']+encoded_df['S FP']+encoded_df['Ceil FP']+encoded_df['Floor FP']+encoded_df['Avg Proj'])/5)
#relevant_df['Avg L5 PPG'] = ((encoded_df['L5_ppg_floor']+encoded_df['L5_ppg_avg']+encoded_df['L5_ppg_max'])/3)

# %%
corr_matrix = relevant_df.corr()

# %%
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow0_col0 {
#             background-color:  #b40426;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow0_col1 {
#             background-color:  #cfdaea;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow0_col2 {
#             background-color:  #3b4cc0;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow0_col3 {
#             background-color:  #3b4cc0;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow0_col4 {
#             background-color:  #3b4cc0;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow0_col5 {
#             background-color:  #6485ec;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow0_col6 {
#             background-color:  #3b4cc0;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow0_col7 {
#             background-color:  #3b4cc0;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow0_col8 {
#             background-color:  #3b4cc0;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow1_col0 {
#             background-color:  #edd1c2;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow1_col1 {
#             background-color:  #b40426;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow1_col2 {
#             background-color:  #7da0f9;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow1_col3 {
#             background-color:  #88abfd;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow1_col4 {
#             background-color:  #85a8fc;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow1_col5 {
#             background-color:  #5673e0;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow1_col6 {
#             background-color:  #7a9df8;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow1_col7 {
#             background-color:  #89acfd;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow1_col8 {
#             background-color:  #6384eb;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow2_col0 {
#             background-color:  #465ecf;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow2_col1 {
#             background-color:  #4055c8;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow2_col2 {
#             background-color:  #b40426;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow2_col3 {
#             background-color:  #ea7b60;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow2_col4 {
#             background-color:  #ee8468;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow2_col5 {
#             background-color:  #445acc;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow2_col6 {
#             background-color:  #f1ccb8;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow2_col7 {
#             background-color:  #f7b89c;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow2_col8 {
#             background-color:  #edd2c3;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow3_col0 {
#             background-color:  #3b4cc0;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow3_col1 {
#             background-color:  #4055c8;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow3_col2 {
#             background-color:  #ec7f63;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow3_col3 {
#             background-color:  #b40426;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow3_col4 {
#             background-color:  #c32e31;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow3_col5 {
#             background-color:  #4055c8;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow3_col6 {
#             background-color:  #f39475;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow3_col7 {
#             background-color:  #ec7f63;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow3_col8 {
#             background-color:  #f7aa8c;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow4_col0 {
#             background-color:  #3e51c5;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow4_col1 {
#             background-color:  #4257c9;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow4_col2 {
#             background-color:  #ef886b;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow4_col3 {
#             background-color:  #c32e31;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow4_col4 {
#             background-color:  #b40426;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow4_col5 {
#             background-color:  #4055c8;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow4_col6 {
#             background-color:  #ebd3c6;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow4_col7 {
#             background-color:  #f29072;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow4_col8 {
#             background-color:  #f5c4ac;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow5_col0 {
#             background-color:  #90b2fe;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow5_col1 {
#             background-color:  #3b4cc0;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow5_col2 {
#             background-color:  #6485ec;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow5_col3 {
#             background-color:  #6c8ff1;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow5_col4 {
#             background-color:  #688aef;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow5_col5 {
#             background-color:  #b40426;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow5_col6 {
#             background-color:  #6687ed;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow5_col7 {
#             background-color:  #7da0f9;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow5_col8 {
#             background-color:  #4358cb;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow6_col0 {
#             background-color:  #4e68d8;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow6_col1 {
#             background-color:  #455cce;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow6_col2 {
#             background-color:  #f2c9b4;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow6_col3 {
#             background-color:  #f18d6f;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow6_col4 {
#             background-color:  #efcebd;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow6_col5 {
#             background-color:  #4e68d8;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow6_col6 {
#             background-color:  #b40426;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow6_col7 {
#             background-color:  #f7b194;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow6_col8 {
#             background-color:  #f6bfa6;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow7_col0 {
#             background-color:  #445acc;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow7_col1 {
#             background-color:  #4a63d3;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow7_col2 {
#             background-color:  #f7b99e;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow7_col3 {
#             background-color:  #eb7d62;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow7_col4 {
#             background-color:  #f18f71;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow7_col5 {
#             background-color:  #5b7ae5;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow7_col6 {
#             background-color:  #f7b497;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow7_col7 {
#             background-color:  #b40426;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow7_col8 {
#             background-color:  #bad0f8;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow8_col0 {
#             background-color:  #5e7de7;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow8_col1 {
#             background-color:  #3e51c5;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow8_col2 {
#             background-color:  #f2cbb7;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow8_col3 {
#             background-color:  #f59d7e;
#         }    #T_6a2f46ca_576c_11ea_acd7_88e9fe6d8b2brow8_col4 {
#             bac

# %%
relevant_df.describe()
# Out:
#         Player Name          team     Actual FP      Avg Proj        Salary  \
# count  13678.000000  13678.000000  13678.000000  13678.000000  13678.000000
# mean     192.646001     14.418044     22.872518     22.874039   4915.762538
# std      122.343606      8.644691     14.423364     11.932305   1851.378584
# min        0.000000      0.000000     -1.000000      0.250000   3000.000000
# 25%       91.000000      7.000000     12.000000     14.450000   3400.000000
# 50%      180.000000     14.000000     20.800000     21.300000   4400.000000
# 75%      290.000000     22.000000     31.500000     29.950000   6000.000000
# max      462.000000     29.000000     92.500000     71.600000  13000.000000
#
#                 Pos  Avg Value Proj  Avg Skewed Min   FPP Per Min
# count  13678.000000    13678.000000    13678.000000  1.367800e+04
# mean       4.553005        4.443027       23.415217           inf
# std        2.896916        1.211902        8.844630           NaN
# min        0.000000        0.085000        0.000000  3.125000e-02
# 25%        3.000000        4.105000       17.333333  7.475902e-01
# 50%        4.000000        4.775000       24.333333  9.111407e-01
# 75%        7.000000        5.145000       30.666667  1.102941e+00
# max        9.000000        9.725000       45.000000           inf

# %%
runLinearRegression(relevant_df, False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-9aebca0d0804> in <module>
# ----> 1 runLinearRegression(relevant_df, False)
#
# <ipython-input-5-515f7567e458> in runLinearRegression(df, needed)
#       6         features = encodeFeatures(cleanFeatures(features))
#       7     lin_reg = LinearRegression()
# ----> 8     lin_reg.fit(features, labels)
#       9     lin_scores = cross_val_score(lin_reg, features, labels, scoring='neg_mean_squared_error', cv=10)
#      10     lin_rmse_scores = np.sqrt(-lin_scores)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     571         if force_all_finite:
#     572             _assert_all_finite(array,
# --> 573                                allow_nan=force_all_finite == 'allow-nan')
#     574
#     575     shape_repr = _shape_repr(array.shape)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57
#      58
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
