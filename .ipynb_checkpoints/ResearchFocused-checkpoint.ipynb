# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from math import floor

drop_attribs = [
    "Player Name",             
    "injury_status",           
    "team",                    
    "opp",                     
    "spread",                
    "over_under",              
    "implied_team_score",      
    "L5_dvp_rank",             
    "L5_ppg_floor",            
    "L5_ppg_avg",              
    "L5_ppg_max",              
    "Pos",                    
    "Salary",                  
    "Rest",                    
    "Opp Pace",                
    "Opp DEff",               
    "Opp DvP",                 
    "L2 FGA",                  
    "L5 FGA",               
    "S FGA", 
    "L2 Min",                 
    "L5 Min",                  
    "S Min",                   
    "L5 FP",                   
    "S FP",                    
    "Floor FP",                
    "Ceil FP",                 
    "Actual Min",             
    "Actual FP",               
    "Actual Val",            
    "FantasyFuelPPGProj",      
    "FantasyFuelValueProj", 
    "DFN_PPGProj",      
    "DFN_MinProj",          
    "DFN_ValueProj",          
]

# %%
def openBestLineupsForDate():
    file_name = 'BestLineups/2020-02-04'
    file = pd.read_csv(file_name,index_col=[0,1], skipinitialspace=True)
    return file
def openCreatedLineupsForDate():
    file_name = 'BestCreatedLineups/2020-02-04'
    file = pd.read_csv(file_name,index_col=[0,1], skipinitialspace=True)
    return file

# %%
def dropLowScoringLineups(file):
    drop_level = file.groupby(['Lineup Num'])['Actual FP'].sum().mean() - file.groupby(['Lineup Num'])['Actual FP'].sum().std()
    group = file.groupby(['Lineup Num'])
    return group.filter(lambda x: x['Actual FP'].sum() > drop_level)

def plotLineupActualFP(file):
    file.groupby(['Lineup Num'])['Actual FP'].sum().plot(style='.')
    print(file.groupby(['Lineup Num'])['Actual FP'].sum().mean())
    print(file.groupby(['Lineup Num'])['Actual FP'].sum().max())
    
def plotLineupProjectedFP(file, projectionType):
    file.groupby(['Lineup Num'])[projectionType].sum().plot(style='.')

# %%
actual = openBestLineupsForDate()
created = openCreatedLineupsForDate()

# %%
actual = dropLowScoringLineups(actual)
plotLineupActualFP(actual)
# Out:
# 344.9117647058824
# 373.2

# %%
plotLineupActualFP(created)
# Out:
# 232.44594594594594
# 291.6

# %%
plotLineupProjectedFP(actual, "FantasyFuelPPGProj")

# %%
plotLineupProjectedFP(created, 'Avg Proj')

# %%
actual.loc[0]['Actual FP'].sum()
# Out:
# 373.2

# %%
created.loc[0]['Actual FP'].sum()
# Out:
# 255.29999999999998

# %%
a = set(actual['Player Name'].value_counts().keys().tolist())
b = set(created['Player Name'].value_counts().keys().tolist())
print(a.intersection(b))
# Out:
# {'Josh Hart', 'Zion Williamson', 'Donte DiVincenzo', 'Rajon Rondo', 'Dwayne Bacon', 'Malik Beasley', 'Miles Bridges', 'Sterling Brown', 'Nikola Jokic', 'Lonnie Walker IV', 'Bryn Forbes', 'James Harden', 'Lonzo Ball', 'JJ Redick', 'Kyle Korver', 'Torrey Craig', 'Jrue Holiday', 'Damian Lillard', "Devonte' Graham", 'Pat Connaughton', 'LaMarcus Aldridge', 'Giannis Antetokounmpo', 'Wesley Matthews', 'Jerami Grant', 'DeMar DeRozan', 'PJ Washington', 'Trevor Ariza', 'Brandon Ingram', 'Danny Green', 'Dejounte Murray', 'Terry Rozier', 'Brook Lopez', 'LeBron James', 'Austin Rivers', 'Danuel House Jr.', 'JaVale McGee', 'Malik Monk', 'Eric Gordon', 'Cody Martin', 'Hassan Whiteside', 'Kyle Kuzma', 'Khris Middleton', 'Ben McLemore'}

# %%
a.symmetric_difference(b)
# Out:
# {'Alex Caruso',
#  'Anfernee Simons',
#  'Anthony Davis',
#  'CJ McCollum',
#  'Carmelo Anthony',
#  'Derrick White',
#  'Dwight Howard',
#  "E'Twaun Moore",
#  'Eric Bledsoe',
#  'Ersan Ilyasova',
#  'Gary Trent Jr.',
#  'Jamal Murray',
#  'Jarred Vanderbilt',
#  'Juancho Hernangomez',
#  'Kentavious Caldwell-Pope',
#  'Marco Belinelli',
#  'Monte Morris',
#  'Nassir Little',
#  'P.J. Tucker',
#  'Quinn Cook',
#  'Trey Lyles',
#  'Will Barton'}

# %%
a.difference(b)
# Out:
# {'Anfernee Simons',
#  'Derrick White',
#  'Juancho Hernangomez',
#  'P.J. Tucker',
#  'Will Barton'}

# %%
actual['Player Name'].value_counts()
# Out:
# James Harden             30
# P.J. Tucker              30
# Danuel House Jr.         28
# Kyle Kuzma               23
# Nikola Jokic             21
# Brandon Ingram           20
# Miles Bridges            13
# Ben McLemore             13
# Malik Beasley            11
# Terry Rozier              7
# Josh Hart                 7
# Malik Monk                6
# Juancho Hernangomez       4
# LeBron James              4
# Austin Rivers             4
# Rajon Rondo               3
# Wesley Matthews           3
# Donte DiVincenzo          3
# Lonzo Ball                3
# Cody Martin               2
# Trevor Ariza              2
# Giannis Antetokounmpo     2
# Khris Middleton           2
# Bryn Forbes               2
# JJ Redick                 2
# Torrey Craig              2
# Kyle Korver               2
# Hassan Whiteside          2
# PJ Washington             2
# Brook Lopez               1
# Derrick White             1
# Dwayne Bacon              1
# Will Barton               1
# Danny Green               1
# Sterling Brown            1
# Zion Williamson           1
# JaVale McGee              1
# Anfernee Simons           1
# Jrue Holiday              1
# Damian Lillard            1
# Devonte' Graham           1
# Eric Gordon               1
# Pat Connaughton           1
# Jerami Grant              1
# Lonnie Walker IV          1
# DeMar DeRozan             1
# LaMarcus Aldridge         1
# Dejounte Murray           1
# Name: Player Name, dtype: int64

# %%
created['Player Name'].value_counts()
# Out:
# Anthony Davis               26
# Kentavious Caldwell-Pope    19
# Austin Rivers               17
# James Harden                15
# Zion Williamson             15
# LaMarcus Aldridge           14
# Donte DiVincenzo            14
# Eric Gordon                 11
# Dejounte Murray              9
# CJ McCollum                  9
# Ben McLemore                 9
# PJ Washington                9
# Jrue Holiday                 8
# LeBron James                 8
# Jerami Grant                 7
# Danuel House Jr.             6
# Pat Connaughton              6
# Giannis Antetokounmpo        5
# Miles Bridges                5
# JJ Redick                    5
# Josh Hart                    5
# Trey Lyles                   4
# Khris Middleton              4
# Trevor Ariza                 4
# Nikola Jokic                 4
# Danny Green                  3
# Brandon Ingram               3
# Carmelo Anthony              3
# Ersan Ilyasova               3
# Kyle Kuzma                   3
# DeMar DeRozan                3
# E'Twaun Moore                3
# Marco Belinelli              2
# Dwayne Bacon                 2
# Malik Beasley                2
# Eric Bledsoe                 2
# Cody Martin                  2
# Monte Morris                 2
# Gary Trent Jr.               2
# Devonte' Graham              2
# Torrey Craig                 2
# Malik Monk                   1
# Nassir Little                1
# Quinn Cook                   1
# Jamal Murray                 1
# Kyle Korver                  1
# Rajon Rondo                  1
# Brook Lopez                  1
# Dwight Howard                1
# JaVale McGee                 1
# Lonzo Ball                   1
# Damian Lillard               1
# Wesley Matthews              1
# Sterling Brown               1
# Hassan Whiteside             1
# Alex Caruso                  1
# Lonnie Walker IV             1
# Bryn Forbes                  1
# Terry Rozier                 1
# Jarred Vanderbilt            1
# Name: Player Name, dtype: int64

# %%
344.3
373.2

245 -> 244
316.7 -> 333


360
386

277 - 291
364 - 367
# Out:
#   File "<ipython-input-102-f777b87b0aa6>", line 4
#     245 -> 244
#          ^
# SyntaxError: invalid syntax

# %%
actual.loc[0]
# Out:
#                    Player Name injury_status team  opp  spread  over_under  \
# Unnamed: 1
# 0                 Caris LeVert           NaN  BKN  PHO    -2.5       224.5
# 1                 Jimmy Butler           NaN  MIA  PHI    -2.5       212.0
# 2                Mikal Bridges           NaN  PHO  BKN     2.5       224.5
# 3           Kristaps Porzingis           NaN  DAL  IND     5.5       211.5
# 4             Dennis Smith Jr.           NaN   NY  CLE     2.0       215.5
# 5            LaMarcus Aldridge           NaN   SA  LAC     9.0       228.5
# 6                Deandre Ayton           NaN  PHO  BKN     2.5       224.5
# 7                 Aaron Gordon           NaN  ORL  CHA    -4.5       202.5
#
#             implied_team_score  L5_dvp_rank  L5_ppg_floor  L5_ppg_avg  \
# Unnamed: 1
# 0                        113.5           20          11.8        15.6
# 1                        107.3           12          34.8        39.5
# 2                        111.0           20          12.0        22.4
# 3                        103.0           12          13.8        33.0
# 4                        106.8           27           0.8        10.3
# 5                        109.8            2          21.8        34.9
# 6                        111.0            9          30.0        41.0
# 7                        103.5            9          18.5        29.1
#
#                 ...        Floor FP Ceil FP  Actual Min  Actual FP  \
# Unnamed: 1      ...
# 0               ...            15.3    32.4        32.0       45.8
# 1               ...            33.0    52.3        28.6       56.8
# 2               ...             9.0    27.4        36.2       37.0
# 3               ...            25.0    48.6        36.4       59.0
# 4               ...             4.1    21.9        20.0       35.3
# 5               ...            26.9    48.4        33.6       50.3
# 6               ...            32.0    49.9        34.3       57.8
# 7               ...            22.0    38.7        37.6       44.5
#
#             Actual Val  FantasyFuelPPGProj FantasyFuelValueProj  DFN_PPGProj  \
# Unnamed: 1
# 0                  9.7                25.8                 5.48         28.1
# 1                  7.0                39.3                 4.85         41.0
# 2                  8.2                23.5                 5.22         23.4
# 3                  8.4                40.8                 5.82         42.4
# 4                  9.8                16.0                 4.44         14.5
# 5                  7.3                38.8                 5.62         36.0
# 6                  7.5                45.3                 5.88         45.0
# 7                  7.3                33.8                 5.53         31.5
#
#             DFN_MinProj  DFN_ValueProj
# Unnamed: 1
# 0                  28.5            6.0
# 1                  34.5            5.1
# 2                  33.5            5.2
# 3                  33.0            6.1
# 4                  15.5            4.0
# 5                  33.0            5.2
# 6                  35.5            5.8
# 7                  34.0            5.2
#
# [8 rows x 35 columns]

# %%
created.loc[8]
# Out:
#                    Player Name injury_status team  opp  spread  over_under  \
# Unnamed: 1
# 0                   Alec Burks           NaN   GS  WAS     6.0       235.0
# 1               Brad Wanamaker           NaN  BOS  ATL    -5.0       229.5
# 2                 Bradley Beal           NaN  WAS   GS    -6.0       235.0
# 3                   Kevin Love           NaN  CLE   NY    -2.0       215.5
# 4               Markelle Fultz           NaN  ORL  CHA    -4.5       202.5
# 5           Kristaps Porzingis           NaN  DAL  IND     5.5       211.5
# 6                Deandre Ayton           NaN  PHO  BKN     2.5       224.5
# 7               Furkan Korkmaz           NaN  PHI  MIA     2.5       212.0
#
#             implied_team_score  L5_dvp_rank  L5_ppg_floor  L5_ppg_avg  \
# Unnamed: 1
# 0                        114.5           29          18.5        24.7
# 1                        117.3           25          -0.5        11.3
# 2                        120.5            9          51.0        56.8
# 3                        108.8           10          24.0        35.4
# 4                        103.5            5          19.0        24.5
# 5                        103.0           12          13.8        33.0
# 6                        111.0            9          30.0        41.0
# 7                        104.8           21           4.8        17.0
#
#                ...      Actual Min Actual FP  Actual Val  DFN_MinProj  \
# Unnamed: 1     ...
# 0              ...            29.0      42.3         8.0         28.0
# 1              ...            27.5      35.3         9.8         26.0
# 2              ...            39.3      58.5         5.8         35.5
# 3              ...            41.4      63.3         8.9         34.0
# 4              ...            34.7      39.3         7.3         31.5
# 5              ...            36.4      59.0         8.4         33.0
# 6              ...            34.3      57.8         7.5         35.5
# 7              ...            16.1      12.0         3.2         22.0
#
#             Avg Proj  Avg Value Proj Avg Skewed Min  Avg Skewed FGA  \
# Unnamed: 1
# 0              33.30           6.300      26.333333       11.000000
# 1              21.45           5.975      18.333333        5.333333
# 2              50.80           5.050      35.333333       21.666667
# 3              40.45           5.680      30.666667       13.333333
# 4              28.90           5.330      29.666667       10.000000
# 5              41.60           5.960      28.666667       14.333333
# 6              45.15           5.840      34.333333       18.000000
# 7              16.40           4.415      23.000000        8.333333
#
#             Avg Skewed FP  Avg L5 PPG
# Unnamed: 1
# 0                   29.56   23.833333
# 1                   15.55   12.200000
# 2                   50.24   56.700000
# 3                   37.61   33.233333
# 4                   26.16   24.666667
# 5                   37.00   34.266667
# 6                   41.79   40.266667
# 7                   15.92   16.266667
#
# [8 rows x 34 columns]
