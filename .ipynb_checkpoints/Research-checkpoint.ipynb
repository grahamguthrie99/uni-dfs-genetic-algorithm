# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from math import floor

drop_attribs = [
    "Player Name",             
    "injury_status",           
    "team",                    
    "opp",                     
    "spread",                
    "over_under",              
    "implied_team_score",      
    "L5_dvp_rank",             
    "L5_ppg_floor",            
    "L5_ppg_avg",              
    "L5_ppg_max",              
    "Pos",                    
    "Salary",                  
    "Rest",                    
    "Opp Pace",                
    "Opp DEff",               
    "Opp DvP",                 
    "L2 FGA",                  
    "L5 FGA",               
    "S FGA", 
    "L2 Min",                 
    "L5 Min",                  
    "S Min",                   
    "L5 FP",                   
    "S FP",                    
    "Floor FP",                
    "Ceil FP",                 
    "Actual Min",             
    "Actual FP",               
    "Actual Val",            
    "FantasyFuelPPGProj",      
    "FantasyFuelValueProj", 
    "DFN_PPGProj",      
    "DFN_MinProj",          
    "DFN_ValueProj",          
]

# %%
def openBestLineupsForDate():
    file_name = 'BestLineups/2020-01-31'
    file = pd.read_csv(file_name,index_col=[0,1], skipinitialspace=True)
    return file

df = openBestLineupsForDate()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 336 entries, (0, 0) to (41, 7)
# Data columns (total 35 columns):
# Player Name             336 non-null object
# injury_status           13 non-null object
# team                    336 non-null object
# opp                     336 non-null object
# spread                  336 non-null float64
# over_under              336 non-null float64
# implied_team_score      336 non-null float64
# L5_dvp_rank             336 non-null int64
# L5_ppg_floor            336 non-null float64
# L5_ppg_avg              336 non-null float64
# L5_ppg_max              336 non-null float64
# Pos                     336 non-null object
# Salary                  336 non-null int64
# Rest                    336 non-null int64
# Opp Pace                336 non-null int64
# Opp DEff                336 non-null int64
# Opp DvP                 336 non-null object
# L2 FGA                  336 non-null int64
# L5 FGA                  336 non-null int64
# ...

# %%
def dropLowScoringLineups(file):
    drop_level = file.groupby(['Lineup Num'])['Actual FP'].sum().mean() - file.groupby(['Lineup Num'])['Actual FP'].sum().std()
    group = file.groupby(['Lineup Num'])
    return group.filter(lambda x: x['Actual FP'].sum() > drop_level)

def plotLineupActualFP(file):
    file.groupby(['Lineup Num'])['Actual FP'].sum().plot()
    
df = dropLowScoringLineups(df)
plotLineupActualFP(df)

# %%
drop_attribs_betting = [
    "Player Name",             
    "injury_status",           
    "team",                    
    "opp",                     
    "L5_dvp_rank",             
    "L5_ppg_floor",            
    "L5_ppg_avg",              
    "L5_ppg_max",              
    "Pos",                                       
    "Opp Pace",                
    "Opp DEff",               
    "Opp DvP",                 
    "L2 FGA",                  
    "L5 FGA",               
    "S FGA", 
    "L2 Min",                 
    "L5 Min",                  
    "S Min",                   
    "L5 FP",                   
    "S FP",                    
    "Floor FP",                
    "Ceil FP",                 
    "Actual Min",             
    "Actual FP",               
    "Actual Val",            
    "FantasyFuelPPGProj",      
    "FantasyFuelValueProj", 
    "DFN_PPGProj",      
    "DFN_MinProj",          
    "DFN_ValueProj",          
]

df.drop(drop_attribs_betting, axis=1).hist(figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x142f18978>,
# ...
#       dtype=object)

# %%
drop_attribs_stats = [
    "Player Name",             
    "injury_status",           
    "team",                    
    "opp",                     
    "spread",                
    "over_under",              
    "implied_team_score",             
    "L5_ppg_floor",            
    "L5_ppg_avg",              
    "L5_ppg_max",              
    "Pos",                    
    "Salary",                  
    "Rest",                                   
    "L5 FP",                   
    "S FP",                    
    "Floor FP",                
    "Ceil FP",                 
    "Actual Min",             
    "Actual FP",               
    "Actual Val",            
    "FantasyFuelPPGProj",      
    "FantasyFuelValueProj", 
    "DFN_PPGProj",      
    "DFN_MinProj",          
    "DFN_ValueProj",          
]

df.drop(drop_attribs_stats, axis=1).hist(figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x143299828>,
# ...
#       dtype=object)

# %%
drop_attribs_fantasy = [
    "Player Name",             
    "injury_status",           
    "team",                    
    "opp",                     
    "spread",                
    "over_under",              
    "implied_team_score",      
    "L5_dvp_rank",                          
    "Pos",                    
    "Salary",                  
    "Rest",                    
    "Opp Pace",                
    "Opp DEff",               
    "Opp DvP",                 
    "L2 FGA",                  
    "L5 FGA",               
    "S FGA", 
    "L2 Min",                 
    "L5 Min",                  
    "S Min",                   
    "L5 FP",                   
    "S FP",                                    
    "Actual Min",             
    "Actual FP",               
    "Actual Val",            
    "FantasyFuelPPGProj",      
    "FantasyFuelValueProj", 
    "DFN_PPGProj",      
    "DFN_MinProj",          
    "DFN_ValueProj",          
]

df.drop(drop_attribs_fantasy, axis=1).hist(figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14367eb38>,
# ...
#       dtype=object)

# %%
df['team'].value_counts().plot(kind='bar')

# %%
df['Player Name'].value_counts().plot(kind='bar')

# %%
df['Pos'].value_counts().plot(kind='bar')

# %%
df.plot(y='Actual FP', x='FantasyFuelPPGProj', style='o')

# %%
df.plot(y='Actual FP', x='DFN_PPGProj', style='o')

# %%
ax = plt.gca()

df.plot(x='Actual FP', y='FantasyFuelPPGProj', style='o', ax=ax)
df.plot(x='Actual FP', y='DFN_PPGProj', style='o' , ax=ax)

plt.show()

# %%
df.plot(y='Actual Min', x='DFN_MinProj', style='o')

# %%
df.plot(y='Actual Val', x='FantasyFuelValueProj', style='o')

# %%
df.plot(y='Actual Val', x='DFN_ValueProj',  style='o')

# %%
df1 = pd.read_csv('BestLineups/2020-02-04',index_col=[0,1], skipinitialspace=True)
df2 = pd.read_csv('BestLineups/2020-02-03',index_col=[0,1], skipinitialspace=True)
df3 = pd.read_csv('BestLineups/2020-02-01',index_col=[0,1], skipinitialspace=True)
df4 = pd.read_csv('BestLineups/2020-01-31',index_col=[0,1], skipinitialspace=True)
df5 = pd.read_csv('BestLineups/2020-01-30',index_col=[0,1], skipinitialspace=True)
df6 = pd.read_csv('BestLineups/2020-01-29',index_col=[0,1], skipinitialspace=True)
df7 = pd.read_csv('BestLineups/2020-01-28',index_col=[0,1], skipinitialspace=True)
df8 = pd.read_csv('BestLineups/2020-01-27',index_col=[0,1], skipinitialspace=True)
df9 = pd.read_csv('BestLineups/2020-01-26',index_col=[0,1], skipinitialspace=True)
df10 = pd.read_csv('BestLineups/2020-01-25',index_col=[0,1], skipinitialspace=True)

# %%
dfx = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10])

# %%
dfx.drop(drop_attribs_betting, axis=1).hist(figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x144d89a90>,
# ...
#       dtype=object)

# %%
df.drop(drop_attribs_stats, axis=1).hist(figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1493589b0>,
# ...
#       dtype=object)

# %%
df.drop(drop_attribs_fantasy, axis=1).hist(figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14977eeb8>,
# ...
#       dtype=object)

# %%
dfx.plot(y='Actual Min', x='DFN_MinProj', style='o')

# %%
corr_matrix = dfx.corr()

# %%
corr_matrix['Actual FP'].sort_values(ascending=False)
# Out:
# Actual FP               1.000000
# DFN_PPGProj             0.843586
# Test Value              0.843320
# FantasyFuelPPGProj      0.837365
# Test Value2             0.827710
# Salary                  0.817024
# Ceil FP                 0.793452
# S FP                    0.792102
# Floor FP                0.780838
# L5 FP                   0.758812
# L5_ppg_avg              0.751065
# S FGA                   0.747368
# Actual Min              0.744382
# L5_ppg_max              0.729517
# L5 FGA                  0.715637
# L2 FGA                  0.713613
# DFN_MinProj             0.689847
# Test Value3             0.687641
# L5_ppg_floor            0.675662
# S Min                   0.660077
# L2 Min                  0.656117
# L5 Min                  0.637197
# Actual Val              0.567885
# DFN_ValueProj           0.404783
# FantasyFuelValueProj    0.333127
# over_under              0.145499
# implied_team_score      0.124019
# Opp DEff                0.092887
# ...

# %%
corr_matrix = dfy.corr()
