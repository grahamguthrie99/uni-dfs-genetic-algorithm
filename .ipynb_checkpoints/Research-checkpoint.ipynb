# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from math import floor

drop_attribs = [
    "Player Name",             
    "injury_status",           
    "team",                    
    "opp",                     
    "spread",                
    "over_under",              
    "implied_team_score",      
    "L5_dvp_rank",             
    "L5_ppg_floor",            
    "L5_ppg_avg",              
    "L5_ppg_max",              
    "Pos",                    
    "Salary",                  
    "Rest",                    
    "Opp Pace",                
    "Opp DEff",               
    "Opp DvP",                 
    "L2 FGA",                  
    "L5 FGA",               
    "S FGA", 
    "L2 Min",                 
    "L5 Min",                  
    "S Min",                   
    "L5 FP",                   
    "S FP",                    
    "Floor FP",                
    "Ceil FP",                 
    "Actual Min",             
    "Actual FP",               
    "Actual Val",            
    "FantasyFuelPPGProj",      
    "FantasyFuelValueProj", 
    "DFN_PPGProj",      
    "DFN_MinProj",          
    "DFN_ValueProj",          
]

# %%
def openBestLineupsForDate():
    file_name = 'BestLineups/2020-02-04'
    file = pd.read_csv(file_name,index_col=[0,1], skipinitialspace=True)
    return file
def openCreatedLineupsForDate():
    file_name = 'BestCreatedLineups/2020-02-04'
    file = pd.read_csv(file_name,index_col=[0,1], skipinitialspace=True)
    return file

# %%
def dropLowScoringLineups(file):
    drop_level = file.groupby(['Lineup Num'])['Actual FP'].sum().mean() - file.groupby(['Lineup Num'])['Actual FP'].sum().std()
    group = file.groupby(['Lineup Num'])
    return group.filter(lambda x: x['Actual FP'].sum() > drop_level)

def plotLineupActualFP(file):
    file.groupby(['Lineup Num'])['Actual FP'].sum().plot(style='.')
    print(file.groupby(['Lineup Num'])['Actual FP'].sum().mean())
    print(file.groupby(['Lineup Num'])['Actual FP'].sum().max())
    
def plotLineupProjectedFP(file, projectionType):
    file.groupby(['Lineup Num'])[projectionType].sum().plot(style='.')

# %%
actual = openBestLineupsForDate()
created = openCreatedLineupsForDate()

# %%
actual = dropLowScoringLineups(actual)
plotLineupActualFP(actual)
# Out:
# 344.9117647058824
# 373.2

# %%
plotLineupActualFP(created)
# Out:
# 252.27906976744183
# 308.2

# %%
plotLineupProjectedFP(actual, "FantasyFuelPPGProj")

# %%
plotLineupProjectedFP(created, 'Avg Proj')

# %%
actual.loc[0]['Actual FP'].sum()
# Out:
# 373.2

# %%
created.loc[0]['Actual FP'].sum()
# Out:
# 251.7

# %%
a = set(actual['Player Name'].value_counts().keys().tolist())
b = set(created['Player Name'].value_counts().keys().tolist())
print(a.intersection(b))
# Out:
# {'Josh Hart', 'Zion Williamson', 'Donte DiVincenzo', 'Rajon Rondo', 'Malik Beasley', 'Miles Bridges', 'Sterling Brown', 'Nikola Jokic', 'Bryn Forbes', 'James Harden', 'P.J. Tucker', 'Lonzo Ball', 'JJ Redick', 'Kyle Korver', 'Torrey Craig', 'Jrue Holiday', 'Damian Lillard', "Devonte' Graham", 'Pat Connaughton', 'LaMarcus Aldridge', 'Giannis Antetokounmpo', 'Wesley Matthews', 'DeMar DeRozan', 'Brandon Ingram', 'Danny Green', 'Dejounte Murray', 'Terry Rozier', 'Will Barton', 'Brook Lopez', 'LeBron James', 'Austin Rivers', 'Derrick White', 'Anfernee Simons', 'Malik Monk', 'Eric Gordon', 'Cody Martin', 'Kyle Kuzma', 'Khris Middleton', 'Ben McLemore'}

# %%
a.symmetric_difference(b)
# Out:
# {'Alex Caruso',
#  'Anthony Davis',
#  'Avery Bradley',
#  'CJ McCollum',
#  'Caleb Swanigan',
#  'Carmelo Anthony',
#  'Danuel House Jr.',
#  'Derrick Favors',
#  'Dwayne Bacon',
#  'Dwight Howard',
#  "E'Twaun Moore",
#  'Eric Bledsoe',
#  'Ersan Ilyasova',
#  'Gary Harris',
#  'Gary Trent Jr.',
#  'Hassan Whiteside',
#  'JaVale McGee',
#  'Jakob Poeltl',
#  'Jarred Vanderbilt',
#  'Jerami Grant',
#  'Juancho Hernangomez',
#  'Kentavious Caldwell-Pope',
#  'Lonnie Walker IV',
#  'Marco Belinelli',
#  'PJ Washington',
#  'Patty Mills',
#  'Robin Lopez',
#  'Rudy Gay',
#  'Thabo Sefolosha',
#  'Trevor Ariza',
#  'Trey Lyles',
#  'Troy Daniels'}

# %%
a.difference(b)
# Out:
# {'Danuel House Jr.',
#  'Dwayne Bacon',
#  'Hassan Whiteside',
#  'JaVale McGee',
#  'Jerami Grant',
#  'Juancho Hernangomez',
#  'Lonnie Walker IV',
#  'PJ Washington',
#  'Trevor Ariza'}

# %%
actual['Salary'].value_counts()
# Out:
# 4400     30
# 12000    30
# 5100     28
# 4000     23
# 10000    21
# 7000     20
# 3300     15
# 5300     15
# 3400     13
# 4700      7
# 4300      7
# 6400      7
# 3000      6
# 3100      6
# 3600      4
# 10100     4
# 4100      3
# 4200      3
# 6700      3
# 3500      3
# 7300      2
# 3700      2
# 3200      2
# 4600      2
# 11400     2
# 4800      2
# 8500      2
# 6800      1
# 6900      1
# 5700      1
# 10300     1
# 6200      1
# 6500      1
# 5000      1
# 7700      1
# 7100      1
# 3800      1
# Name: Salary, dtype: int64

# %%
actual.loc[0]['Salary']
# Out:
# Unnamed: 1
# 0     4300
# 1    12000
# 2     5100
# 3     4000
# 4     3400
# 5     5300
# 6    10000
# 7     4400
# Name: Salary, dtype: int64

# %%
created['Salary'].value_counts()
# Out:
# 3400     29
# 4400     29
# 7100     26
# 9300     25
# 5300     22
# 6200     20
# 10100    17
# 4000     15
# 12000    15
# 6900     15
# 3300     12
# 3500     12
# 3000     10
# 4300      9
# 6300      8
# 6700      6
# 7300      6
# 4700      6
# 11400     5
# 6800      5
# 3800      5
# 3600      5
# 3100      4
# 7000      4
# 3200      4
# 4900      3
# 7700      3
# 4200      3
# 5000      3
# 6400      3
# 10300     2
# 6600      2
# 10000     2
# 3900      2
# 6500      2
# 5500      2
# 4100      2
# 3700      1
# Name: Salary, dtype: int64

# %%
344.3
373.2

245 -> 244
316.7 -> 333


360
386

277 - 291
364 - 367
# Out:
#   File "<ipython-input-445-f777b87b0aa6>", line 4
#     245 -> 244
#          ^
# SyntaxError: invalid syntax

# %%
actual.loc[0]
# Out:
#                  Player Name injury_status team  opp  spread  over_under  \
# Unnamed: 1
# 0                 Malik Monk           NaN  CHA  HOU    13.5       222.5
# 1               James Harden           NaN  HOU  CHA   -13.5       222.5
# 2           Danuel House Jr.           NaN  HOU  CHA   -13.5       222.5
# 3                 Kyle Kuzma           NaN  LAL   SA   -11.0       226.0
# 4               Ben McLemore           NaN  HOU  CHA   -13.5       222.5
# 5              Miles Bridges           NaN  CHA  HOU    13.5       222.5
# 6               Nikola Jokic           NaN  DEN  POR    -5.0       225.5
# 7                P.J. Tucker           NaN  HOU  CHA   -13.5       222.5
#
#             implied_team_score  L5_dvp_rank  L5_ppg_floor  L5_ppg_avg  \
# Unnamed: 1
# 0                        104.5           18          16.5        26.2
# 1                        118.0            8          29.0        51.5
# 2                        118.0           16          18.5        30.9
# 3                        118.5           20          12.8        22.1
# 4                        118.0           22          12.5        19.2
# 5                        104.5           23           5.5        28.7
# 6                        115.3            1          43.5        57.6
# 7                        118.0           18          12.8        21.9
#
#                 ...        Floor FP Ceil FP  Actual Min  Actual FP  \
# Unnamed: 1      ...
# 0               ...             6.8    28.2        30.6       28.0
# 1               ...            47.5    76.1        39.8       79.3
# 2               ...            12.2    31.3        42.4       45.8
# 3               ...            12.1    31.2        30.3       40.5
# 4               ...             8.9    27.3        36.7       26.5
# 5               ...            15.2    35.1        39.1       44.8
# 6               ...            34.6    60.2        30.7       69.8
# 7               ...            13.2    32.1        40.8       38.5
#
#             Actual Val  FantasyFuelPPGProj FantasyFuelValueProj  DFN_PPGProj  \
# Unnamed: 1
# 0                  6.5                24.8                 5.76         21.9
# 1                  6.6                68.0                 5.67         70.4
# 2                  9.0                25.3                 4.95         26.4
# 3                 10.1                21.3                 5.31         21.6
# 4                  7.8                21.8                 6.40         19.8
# 5                  8.5                25.8                 4.86         26.7
# 6                  7.0                54.0                 5.40         57.0
# 7                  8.8                25.5                 5.80         26.9
#
#             DFN_MinProj  DFN_ValueProj
# Unnamed: 1
# 0                  25.0            5.1
# 1                  38.0            5.9
# 2                  33.0            5.2
# 3                  24.0            5.4
# 4                  25.5            5.8
# 5                  31.5            5.0
# 6                  35.5            5.7
# 7                  37.0            6.1
#
# [8 rows x 35 columns]

# %%
created.loc[8]
# Out:
#                   Player Name injury_status team  opp  spread  over_under  \
# Unnamed: 1
# 0                 Patty Mills           NaN   SA  LAL    11.0       226.0
# 1                 Cody Martin           NaN  CHA  HOU    13.5       222.5
# 2                Ben McLemore           NaN  HOU  CHA   -13.5       222.5
# 3                 P.J. Tucker           NaN  HOU  CHA   -13.5       222.5
# 4                James Harden           NaN  HOU  CHA   -13.5       222.5
# 5             Zion Williamson           NaN   NO  MIL     6.5       246.0
# 6           LaMarcus Aldridge           NaN   SA  LAL    11.0       226.0
# 7               Anthony Davis             Q  LAL   SA   -11.0       226.0
#
#             implied_team_score  L5_dvp_rank  L5_ppg_floor  L5_ppg_avg  \
# Unnamed: 1
# 0                        107.5           26          19.3        26.3
# 1                        104.5           13           6.0        18.8
# 2                        118.0           22          12.5        19.2
# 3                        118.0           18          12.8        21.9
# 4                        118.0            8          29.0        51.5
# 5                        119.8           22          26.0        33.3
# 6                        107.5           15          21.8        37.8
# 7                        118.5           11          37.8        50.5
#
#                ...      Actual Min Actual FP  Actual Val  DFN_MinProj  \
# Unnamed: 1     ...
# 0              ...            18.9       5.0         1.3         22.5
# 1              ...            36.2      19.3         5.5         27.5
# 2              ...            36.7      26.5         7.8         25.5
# 3              ...            40.8      38.5         8.8         37.0
# 4              ...            39.8      79.3         6.6         38.0
# 5              ...            31.8      36.3         5.1         32.0
# 6              ...            30.2      14.3         2.3         32.5
# 7              ...            29.1      26.3         2.8         35.5
#
#             Avg Proj  Avg Value Proj Avg Skewed Min  Avg Skewed FGA  \
# Unnamed: 1
# 0              17.95           4.500      23.000000       10.666667
# 1              18.40           5.245      21.666667        5.666667
# 2              20.80           6.100      21.666667        9.333333
# 3              26.20           5.950      36.666667        5.666667
# 4              69.20           5.785      37.333333       22.666667
# 5              41.55           5.835      28.333333       13.666667
# 6              35.30           5.685      33.000000       14.000000
# 7              54.80           5.880      34.000000       16.333333
#
#             Avg Skewed FP  Avg L5 PPG
# Unnamed: 1
# 0                   20.93   27.300000
# 1                   14.34   19.600000
# 2                   18.86   19.900000
# 3                   23.22   22.233333
# 4                   61.22   51.833333
# 5                   35.09   32.866667
# 6                   37.40   39.533333
# 7                   52.12   55.766667
#
# [8 rows x 34 columns]
