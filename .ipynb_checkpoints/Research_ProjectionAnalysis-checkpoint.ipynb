# %%
#drop player that is out

# %%
import pandas as pd 
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score

import matplotlib.pyplot as plt

# %%
dates_all = [
    ['2_4', '2020-02-04'],
    ['2_3', '2020-02-03'],
    ['2_2', '2020-02-02'],
    ['2_1', '2020-02-01'],
    ['1_31', '2020-01-31'],
    ['1_30', '2020-01-30'],
    ['1_29', '2020-01-29'],
    ['1_28', '2020-01-28'],
    ['1_27', '2020-01-27'],
    ['1_26', '2020-01-26'],
    ['1_25', '2020-01-25'],
    ['1_24', '2020-01-24'],
    ['1_23', '2020-01-23'],
    ['1_22', '2020-01-22'],
    ['1_20', '2020-01-20'],
    ['1_19', '2020-01-19'],
    ['1_18', '2020-01-18'],
    ['1_17', '2020-01-17'],
    ['1_16', '2020-01-16'],
    ['1_15', '2020-01-15'],
    ['1_14', '2020-01-14'],
    ['1_13', '2020-01-13'],
    ['1_12', '2020-01-12'],
    ['1_11', '2020-01-11'],
    ['1_10', '2020-01-10'],
    ['1_9', '2020-01-09'],
    ['1_8', '2020-01-08'],
    ['1_7', '2020-01-07'],
    ['1_6', '2020-01-06'],
    ['1_5', '2020-01-05'],
    ['1_4', '2020-01-04'],
    ['1_3', '2020-01-03'],
    ['1_2', '2020-01-02'],
    ['1_1', '2020-01-01'],
    ['12_31', '2019-12-31'],
    ['12_30', '2019-12-30'],
    ['12_29', '2019-12-29'],
    ['12_28', '2019-12-28'],
    ['12_27', '2019-12-27'],
    ['12_26', '2019-12-26'],
    ['12_25', '2019-12-25'],
    ['12_23', '2019-12-23'],
    ['12_22', '2019-12-22'],
    ['12_21', '2019-12-21'],
    ['12_20', '2019-12-20'],
    ['12_19', '2019-12-19'],
    ['12_18', '2019-12-18'],
    ['12_17', '2019-12-17'],
    ['12_16', '2019-12-16'],
    ['12_15', '2019-12-15'],
    ['12_14', '2019-12-14'],
    ['12_13', '2019-12-13'],
    ['12_12', '2019-12-12'],
    ['12_11', '2019-12-11'],
    ['12_10', '2019-12-10'],
    ['12_9', '2019-12-09'],
    ['12_8', '2019-12-08'],
    ['12_7', '2019-12-07'],
    ['12_6', '2019-12-06'],
    ['12_5', '2019-12-05'],
    ['12_4', '2019-12-04'],
    ['12_3', '2019-12-03'],
    ['12_2', '2019-12-02'],
    ['12_1', '2019-12-01'],
    ['11_30', '2019-11-30'],
    ['11_29', '2019-11-29'],
    ['11_27', '2019-11-27'],
    ['11_26', '2019-11-26'],
    ['11_25', '2019-11-25'],
    ['11_24', '2019-11-24'],
    ['11_23', '2019-11-23'],
    ['11_22', '2019-11-22'],
    ['11_21', '2019-11-21'],
    ['11_20', '2019-11-20'],
    ['11_19', '2019-11-19'],
    ['11_18', '2019-11-18'],
    ['11_17', '2019-11-17'],
    ['11_16', '2019-11-16'],
    ['11_15', '2019-11-15'],
    ['11_14', '2019-11-14'],
    ['11_13', '2019-11-13'],
    ['11_12', '2019-11-12'],
    ['11_11', '2019-11-11'],
    ['11_10', '2019-11-10'],
    ['11_9', '2019-11-09'],
    ['11_8', '2019-11-08'],
    ['11_7', '2019-11-07'],
    ['11_6', '2019-11-06'],
    ['11_5', '2019-11-05'],
    ['11_4', '2019-11-04'],
    ['11_3', '2019-11-03'],
    ['11_2', '2019-11-02'],
    ['11_1', '2019-11-01'],
    ['10_31', '2019-10-31'],
    ['10_30', '2019-10-30'],
    ['10_29', '2019-10-29'],
    ['10_28', '2019-10-28'],
    ['10_27', '2019-10-27'],
    ['10_26', '2019-10-26'],
    ['10_25', '2019-10-25'],
    ['10_24', '2019-10-24'],
    ['10_23', '2019-10-23'],
    ['10_22', '2019-10-22'],   
]

dates = [
    ['2_3', '2020-02-03'],
 
]

drop_attribs = [
        "game_date",
        'ppg_projection', 
        'value_projection', 
        "position",
        "salary", 
    
        'FantasyFuelValueProj',
        'DFN_ValueProj',
        'Proj Val'
]

# %%
def mergeAllDates():
    file = pd.DataFrame()
    for game_day in dates_all:
        game_date = 'HistoricalData_Merged/{}'.format(game_day[1])
        file = file.append(pd.read_csv(game_date), ignore_index=True)
    return file

def reduceForProjectionAnalysis(file):
    file['FantasyFuelPPGProj'] = file['ppg_projection']
    file['FantasyFuelValueProj'] = file['value_projection']
    file['DFN_PPGProj'] = file['Proj FP']
    file['DFN_ValueProj'] = file['Proj Val']
    file['Avg Proj'] = ((file['DFN_PPGProj']+file['FantasyFuelPPGProj'])/2)
    file['Avg Val'] = ((file['DFN_ValueProj']+file['FantasyFuelValueProj'])/2)
    file.drop(drop_attribs, axis=1, inplace=True)
    file = file[file['injury_status'] != 'O']
    return file

full_df = reduceForProjectionAnalysis(mergeAllDates())

full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13678 entries, 0 to 16564
# Data columns (total 38 columns):
# Player Name           13678 non-null object
# injury_status         656 non-null object
# team                  13678 non-null object
# opp                   13678 non-null object
# spread                13640 non-null float64
# over_under            13640 non-null float64
# implied_team_score    13640 non-null float64
# L5_dvp_rank           13678 non-null int64
# L5_ppg_floor          13650 non-null float64
# L5_ppg_avg            13650 non-null float64
# L5_ppg_max            13650 non-null float64
# Pos                   13678 non-null object
# Salary                13678 non-null int64
# Rest                  13390 non-null float64
# USG                   12329 non-null float64
# PER                   12329 non-null float64
# Opp Pace              13678 non-null int64
# Opp DEff              13678 non-null int64
# Opp DvP               13678 non-null object
# L2 FGA                13678 non-null int64
# L5 FGA                13678 non-null int64
# S FGA                 13678 non-null int64
# L2 Min                13678 non-null int64
# L5 Min                13678 non-null int64
# S Min                 13678 non-null int64
# L5 FP                 13678 non-null float64
# S FP                  13678 non-null float64
# Floor FP              13678 non-null float64
# Ceil FP               13678 non-null float64
# Proj Min              13678 non-null float64
# Proj FP               13678 non-null float64
# Actual Min            13678 non-null float64
# Actual FP             13678 non-null float64
# Actual Val            13678 non-null float64
# FantasyFuelPPGProj    13678 non-null float64
# DFN_PPGProj           13678 non-null float64
# Avg Proj              13678 non-null float64
# Avg Val               13678 non-null float64
# dtypes: float64(22), int64(10), object(6)
# memory usage: 4.1+ MB

# %%
full_df['injury_status'].value_counts()
# Out:
# Q    656
# Name: injury_status, dtype: int64

# %%
def rmse(x,y):
    bench_mse = mean_squared_error(y, x)
    bench_rmse = np.sqrt(bench_mse)
    return bench_rmse


def benchmarks(file):
    bench_proj = full_df['Avg Proj']
    bench_actual = full_df['Actual FP']
    print('FP Proj Error: ',rmse(bench_proj, bench_actual))
    
    bench_val = full_df['Avg Val']
    bench_actual_val = full_df['Actual Val']
    print('FP Val Error: ',rmse(bench_val, bench_actual_val))
    
    bench_min = full_df['Proj Min']
    bench_actual_min = full_df['Actual Min']
    print('FP Min Error: ',rmse(bench_min, bench_actual_min))

##Benchmark
benchmarks(full_df)
# Out:
# FP Proj Error:  9.415489865525222
# FP Val Error:  2.085873636994158
# FP Min Error:  6.082232399188834

# %%
def runLinearRegression(df, needed, label_type):
    train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)
    features = train_set.drop(['Actual FP','Actual Min','Actual Val'], axis=1).copy()
    labels = train_set[label_type].copy()
    if(needed):
        features = encodeFeatures(cleanFeatures(features))
    lin_reg = LinearRegression()
    lin_reg.fit(features, labels)
    lin_scores = cross_val_score(lin_reg, features, labels, scoring='neg_mean_squared_error', cv=10)
    lin_rmse_scores = np.sqrt(-lin_scores)
    display_scores(lin_rmse_scores, label_type)

    
    
def display_scores(scores, label_type):
    print("*", label_type)
    print('Scores:', scores)
    print('Mean:' ,scores.mean())
    print('Std:', scores.std())
    

def cleanFeatures(features): 
    features['L5_ppg_floor'].fillna(0, inplace=True)
    features['L5_ppg_avg'].fillna(0, inplace=True)
    features['L5_ppg_max'].fillna(0, inplace=True)
    features['USG'].fillna(0, inplace=True)
    features['PER'].fillna(0, inplace=True)
    features['spread'].fillna(features['spread'].mean(), inplace=True)
    features['over_under'].fillna(features['over_under'].mean(), inplace=True)
    features['implied_team_score'].fillna(features['implied_team_score'].mean(), inplace=True)
    features['Rest'].fillna(features['Rest'].mean(), inplace=True)
    features['injury_status'].fillna('good', inplace=True)
    return features

def encodeFeatures(features):
    nba_player = features['Player Name']
    nba_injury = features['injury_status']
    nba_team = features['team']
    nba_opp = features['opp']
    nba_pos = features['Pos']
    nba_dvp = features['Opp DvP']
    
    nba_player_encoded, nba_player_categories = nba_player.factorize()
    nba_injury_encoded, nba_injury_categories = nba_injury.factorize()
    nba_team_encoded, nba_team_categories = nba_team.factorize()
    nba_opp_encoded, nba_opp_categories = nba_opp.factorize()
    nba_pos_encoded, nba_pos_categories = nba_pos.factorize()
    nba_dvp_encoded, nba_dvp_categories = nba_dvp.factorize()
    
    features['Player Name'] = nba_player_encoded
    features['injury_status'] = nba_injury_encoded
    features['team'] = nba_team_encoded
    features['opp'] = nba_opp_encoded
    features['Pos'] = nba_pos_encoded
    features['Opp DvP'] = nba_dvp_encoded
    return features

# %%
runLinearRegression(full_df, True, 'Actual FP')
# Out:
# * Actual FP
# Scores: [9.24551509 9.21367176 9.32790473 9.37129894 9.02335249 9.51795244
#  9.56258394 9.31935449 9.03886102 9.73497965]
# Mean: 9.335547454506841
# Std: 0.2131689614519047

# %%
runLinearRegression(full_df, True, 'Actual Val')
# Out:
# * Actual Val
# Scores: [2.05429297 2.0854419  2.02894385 2.11677871 1.94608884 2.02790264
#  2.01876992 2.10253906 2.00528867 2.03683348]
# Mean: 2.042288004370136
# Std: 0.04772475218669453

# %%
runLinearRegression(full_df, True, 'Actual Min')
# Out:
# * Actual Min
# Scores: [5.59277468 5.5026701  5.35774051 5.595939   5.17999538 5.38443733
#  5.44426145 5.44310132 5.27686016 5.83384233]
# Mean: 5.461162225792959
# Std: 0.1750190345449862

# %%
def normalize(df):
    result = df.copy()
    for feature_name in df.columns:
        max_value = df[feature_name].max()
        min_value = df[feature_name].min()
        result[feature_name] = (df[feature_name] - min_value) / (max_value - min_value)
    return result

def standardize(df):
    result = df.copy()
    for feature_name in df.columns:
        mean_value = df[feature_name].mean()
        std_value = df[feature_name].std()
        result[feature_name] = ((df[feature_name] - mean_value) / (std_value))
    return result

# %%
encoded_df = encodeFeatures(cleanFeatures(full_df)).copy()

encoded_df = encoded_df[encoded_df['Avg Proj'] > 5]

runLinearRegression(encoded_df, False, 'Actual FP')
# Out:
# * Actual FP
# Scores: [9.11554607 9.72915926 9.49526251 9.63586762 8.96865169 9.9283112
#  9.05747317 9.61623983 9.60736008 9.41776721]
# Mean: 9.457163863768853
# Std: 0.29897550352670255

# %%
encoded_df = encodeFeatures(cleanFeatures(full_df)).copy()

# %% [markdown]
# Index(['Player Name', 'injury_status', 'team', 'opp', 'spread', 'over_under',
#        'implied_team_score', 'L5_dvp_rank', 'L5_ppg_floor', 'L5_ppg_avg',
#        'L5_ppg_max', 'Pos', 'Salary', 'Rest', 'Opp Pace', 'Opp DEff',
#        'Opp DvP', 'L2 FGA', 'L5 FGA', 'S FGA', 'L2 Min', 'L5 Min', 'S Min',
#        'L5 FP', 'S FP', 'Floor FP', 'Ceil FP', 'Proj Min', 'Proj FP',
#        'Actual Min', 'Actual FP', 'Actual Val', 'FantasyFuelPPGProj',
#        'DFN_PPGProj', 'Avg Proj', 'Avg Val'],
#       dtype='object')

# %% [markdown]
# Floor - Indicates a player’s low-end FP and is a useful measure of a player’s consistency. A player is roughly expected to exceed his floor 84% of the time. Calculated as the season average minus one standard deviation.
#
# Ceil - Indicates a player’s high-end FP and is a useful measure of a player’s upside. A player is roughly expected to exceed his ceiling 16% of the time. Calculated as the season average plus one standard deviation.
#
# [Value] Indicates a player’s bang for buck or salary efficiency. Calculated as the ratio of FP/(Salary/1,000).

# %%
relevant_df = pd.DataFrame()

#relevant_df['Pos'] = encoded_df['Pos']
relevant_df['Actual FP'] = encoded_df['Actual FP']
relevant_df['Actual Val'] = encoded_df['Actual Val']
relevant_df['Actual Min'] = encoded_df['Actual Min']

relevant_df['Avg Proj'] = encoded_df['Avg Proj']
relevant_df['Avg Val'] = encoded_df['Avg Val']
relevant_df['Proj Min'] = encoded_df['Proj Min']


relevant_df['Avg Skewed FP'] = ((encoded_df['L5 FP']+encoded_df['S FP']+encoded_df['Ceil FP']+encoded_df['Floor FP']+encoded_df['Avg Proj'])/5) 

relevant_df['Avg Skewed Min'] = ((encoded_df['L2 Min']+encoded_df['L5 Min']+encoded_df['S Min'])/3)
relevant_df['Avg L5 PPG'] = ((encoded_df['L5_ppg_floor']+encoded_df['L5_ppg_avg']+encoded_df['L5_ppg_max'])/3)
relevant_df['Avg Skewed FGA'] = ((encoded_df['L2 FGA']+encoded_df['L5 FGA']+encoded_df['S FGA'])/3)
relevant_df['USG'] = encoded_df['USG']
relevant_df['PER'] = encoded_df['PER']


relevant_df['Proj FPP Per Min'] = relevant_df['Avg Proj'] / encoded_df['Proj Min']
relevant_df['Proj Min Enhanced'] = (relevant_df['Avg Proj'] / relevant_df['Avg Skewed Min'] ) * encoded_df['Proj Min']
relevant_df['Proj Pts Scores'] = encoded_df['implied_team_score']*(relevant_df['USG'] /100)


relevant_df.replace([np.inf, -np.inf], 0, inplace=True)

relevant_df = relevant_df[relevant_df['Avg Proj'] > 1]
#relevant_df= normalize(relevant_df)
relevant_df= standardize(relevant_df)

# %%
relevant_df.dropna(inplace=True)

# %%
corr_matrix = relevant_df.corr()

# %%
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow0_col1 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow0_col2 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow0_col3 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow0_col4 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow0_col5 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow0_col6 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow0_col7 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow0_col8 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow0_col9 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow0_col10 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow0_col11 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow0_col12 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow0_col13 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow0_col14 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow1_col0 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow1_col2 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow1_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow1_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow1_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow1_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow1_col14 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow2_col0 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow2_col1 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow2_col3 {
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow2_col4 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow2_col5 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow2_col6 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow2_col7 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow2_col8 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow2_col9 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow2_col10 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow2_col11 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow2_col12 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow2_col13 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow2_col14 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow3_col0 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow3_col1 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow3_col2 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow3_col4 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow3_col5 {
#             background-color:  #f18d6f;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow3_col6 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow3_col7 {
#             background-color:  #f7b396;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow3_col8 {
#             background-color:  #da5a49;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow3_col9 {
#             background-color:  #f29274;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow3_col10 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow3_col11 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow3_col12 {
#             background-color:  #f59c7d;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow3_col13 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_cbe5e048_5912_11ea_82e9_88e9fe6d8b2brow3_col14 {
#             background-color:  #f2c9b4;

# %%
runLinearRegression(relevant_df, False, 'Actual FP')
# Out:
# * Actual FP
# Scores: [9.64356924 9.30915731 9.32461488 9.74116169 9.41966938 9.20805647
#  9.40141341 8.98904144 9.37874416 9.27181427]
# Mean: 9.368724225463755
# Std: 0.20071680934331587
