# %%
#drop player that is out

# %%
import pandas as pd 
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
dates = [
    ['2_4', '2020-02-04'],
    ['2_3', '2020-02-03'],
    ['2_2', '2020-02-02'],
    ['2_1', '2020-02-01'],
    ['1_31', '2020-01-31'],
    ['1_30', '2020-01-30'],
    ['1_29', '2020-01-29'],
    ['1_28', '2020-01-28'],
    ['1_27', '2020-01-27'],
    ['1_26', '2020-01-26'],
    ['1_25', '2020-01-25'],
    ['1_24', '2020-01-24'],
    ['1_23', '2020-01-23'],
    ['1_22', '2020-01-22'],
    ['1_20', '2020-01-20'],
    ['1_19', '2020-01-19'],
    ['1_18', '2020-01-18'],
    ['1_17', '2020-01-17'],
    ['1_16', '2020-01-16'],
    ['1_15', '2020-01-15'],
    ['1_14', '2020-01-14'],
    ['1_13', '2020-01-13'],
    ['1_12', '2020-01-12'],
    ['1_11', '2020-01-11'],
    ['1_10', '2020-01-10'],
    ['1_9', '2020-01-09'],
    ['1_8', '2020-01-08'],
    ['1_7', '2020-01-07'],
    ['1_6', '2020-01-06'],
    ['1_5', '2020-01-05'],
    ['1_4', '2020-01-04'],
    ['1_3', '2020-01-03'],
    ['1_2', '2020-01-02'],
    ['1_1', '2020-01-01'],
    ['12_31', '2019-12-31'],
    ['12_30', '2019-12-30'],
    ['12_29', '2019-12-29'],
    ['12_28', '2019-12-28'],
    ['12_27', '2019-12-27'],
    ['12_26', '2019-12-26'],
    ['12_25', '2019-12-25'],
    ['12_23', '2019-12-23'],
    ['12_22', '2019-12-22'],
    ['12_21', '2019-12-21'],
    ['12_20', '2019-12-20'],
    ['12_19', '2019-12-19'],
    ['12_18', '2019-12-18'],
    ['12_17', '2019-12-17'],
    ['12_16', '2019-12-16'],
    ['12_15', '2019-12-15'],
    ['12_14', '2019-12-14'],
    ['12_13', '2019-12-13'],
    ['12_12', '2019-12-12'],
    ['12_11', '2019-12-11'],
    ['12_10', '2019-12-10'],
    ['12_9', '2019-12-09'],
    ['12_8', '2019-12-08'],
    ['12_7', '2019-12-07'],
    ['12_6', '2019-12-06'],
    ['12_5', '2019-12-05'],
    ['12_4', '2019-12-04'],
    ['12_3', '2019-12-03'],
    ['12_2', '2019-12-02'],
    ['12_1', '2019-12-01'],
    ['11_30', '2019-11-30'],
    ['11_29', '2019-11-29'],
    ['11_27', '2019-11-27'],
    ['11_26', '2019-11-26'],
    ['11_25', '2019-11-25'],
    ['11_24', '2019-11-24'],
    ['11_23', '2019-11-23'],
    ['11_22', '2019-11-22'],
    ['11_21', '2019-11-21'],
    ['11_20', '2019-11-20'],
    ['11_19', '2019-11-19'],
    ['11_18', '2019-11-18'],
    ['11_17', '2019-11-17'],
    ['11_16', '2019-11-16'],
    ['11_15', '2019-11-15'],
    ['11_14', '2019-11-14'],
    ['11_13', '2019-11-13'],
    ['11_12', '2019-11-12'],
    ['11_11', '2019-11-11'],
    ['11_10', '2019-11-10'],
    ['11_9', '2019-11-09'],
    ['11_8', '2019-11-08'],
    ['11_7', '2019-11-07'],
    ['11_6', '2019-11-06'],
    ['11_5', '2019-11-05'],
    ['11_4', '2019-11-04'],
    ['11_3', '2019-11-03'],
    ['11_2', '2019-11-02'],
    ['11_1', '2019-11-01'],
    ['10_31', '2019-10-31'],
    ['10_30', '2019-10-30'],
    ['10_29', '2019-10-29'],
    ['10_28', '2019-10-28'],
    ['10_27', '2019-10-27'],
    ['10_26', '2019-10-26'],
    ['10_25', '2019-10-25'],
    ['10_24', '2019-10-24'],
    ['10_23', '2019-10-23'],
    ['10_22', '2019-10-22'],   
]

drop_attribs = [
        "game_date",
        'ppg_projection', 
        'value_projection', 
        'Proj FP', 
        'Proj Min', 
        'Proj Val',
        "position",
        "salary", 
        "Actual Min",
        "Actual Val",
]

# %%
def mergeAllDates():
    file = pd.DataFrame()
    for game_day in dates:
        game_date = 'HistoricalData_Merged/{}'.format(game_day[1])
        file = file.append(addPlayerOccurences(pd.read_csv(game_date), game_day[1]), ignore_index=True)
    return file

def addPlayerOccurences(file, date):
    file['Selected'] = np.nan
    game_date = 'BestLineups/{}'.format(date)
    best_lineups_file = pd.read_csv(game_date,index_col=[0,1], skipinitialspace=True)
    values = best_lineups_file['Player Name'].value_counts().keys().tolist()
    counts = best_lineups_file['Player Name'].value_counts().tolist()
    for i in range(len(values)):
        file.loc[file['Player Name'] == values[i],['Selected']] = counts[i]
    file['Selected'].fillna(0, inplace=True)
    return file
    
def reduceForProjectionAnalysis(file):
    file['FantasyFuelPPGProj'] = file['ppg_projection']
    file['FantasyFuelValueProj'] = file['value_projection']
    file['DFN_PPGProj'] = file['Proj FP']
    file['DFN_MinProj'] = file['Proj Min']
    file['DFN_ValueProj'] = file['Proj Val']
    file.drop(drop_attribs, axis=1, inplace=True)
    #file = file.loc[file['Actual FP'] > 0]
    return file

# %%
full_df = reduceForProjectionAnalysis(mergeAllDates())
full_df['Avg Proj'] = ((full_df['DFN_PPGProj']+full_df['FantasyFuelPPGProj'])/2)
full_df = full_df[full_df['injury_status'] != 'O']

full_df['Selected'] = np.where(full_df['Selected'] > 0, 1,0)

# %%
### Benchmark
print((7881/13678)
# Out:
# 0.576180728176634

# %%
corr_matrix = full_df.corr()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col1 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col9 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col11 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col12 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col14 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col15 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col16 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col17 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col18 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col19 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col20 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col21 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col22 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col23 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col24 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col25 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col26 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col27 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow0_col28 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col0 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col2 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col3 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col4 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col5 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col6 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col7 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col8 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col9 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col10 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col11 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col12 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col13 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col14 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col15 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col16 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col17 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col18 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col19 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col20 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col21 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col22 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col23 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col24 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col25 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col26 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col27 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow1_col28 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5e7e8914_4e2d_11ea_98e0_88e9fe6d8b2brow2_col1 {
#             background-color:  #f2

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_predict

# %%
def runBinaryClassifier(df, needed):
    train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)
    features = train_set.drop(['Actual FP', 'Selected'], axis=1).copy()
    labels = train_set['Selected'].copy()
    if(needed):
        features = encodeFeatures(cleanFeatures(features))
    sgd_clf = SGDClassifier(random_state=42)
    sgd_clf.fit(features, labels)
    sgd_scores = cross_val_score(sgd_clf, features, labels, scoring='accuracy', cv=5)
    sgd_predict = cross_val_predict(sgd_clf, features, labels, cv=5)
    
    displayScores(sgd_scores)
    displayConfusion(sgd_predict, labels)
    
def displayScores(scores):
    print('Scores:', scores)
    print('Mean:' ,scores.mean())
    print('Std:', scores.std())

def displayConfusion(predictions, labels):
    print('Confusion:', confusion_matrix(labels, predictions))

    
def cleanFeatures(features): 
    features['L5_ppg_floor'].fillna(0, inplace=True)
    features['L5_ppg_avg'].fillna(0, inplace=True)
    features['L5_ppg_max'].fillna(0, inplace=True)
    features['spread'].fillna(features['spread'].mean(), inplace=True)
    features['over_under'].fillna(features['over_under'].mean(), inplace=True)
    features['implied_team_score'].fillna(features['implied_team_score'].mean(), inplace=True)
    features['Rest'].fillna(features['Rest'].mean(), inplace=True)
    features['injury_status'].fillna('good', inplace=True)
    return features

def encodeFeatures(features):
    nba_player = features['Player Name']
    nba_injury = features['injury_status']
    nba_team = features['team']
    nba_opp = features['opp']
    nba_pos = features['Pos']
    nba_dvp = features['Opp DvP']
    
    nba_player_encoded, nba_player_categories = nba_player.factorize()
    nba_injury_encoded, nba_injury_categories = nba_injury.factorize()
    nba_team_encoded, nba_team_categories = nba_team.factorize()
    nba_opp_encoded, nba_opp_categories = nba_opp.factorize()
    nba_pos_encoded, nba_pos_categories = nba_pos.factorize()
    nba_dvp_encoded, nba_dvp_categories = nba_dvp.factorize()
    
    features['Player Name'] = nba_player_encoded
    features['injury_status'] = nba_injury_encoded
    features['team'] = nba_team_encoded
    features['opp'] = nba_opp_encoded
    features['Pos'] = nba_pos_encoded
    features['Opp DvP'] = nba_dvp_encoded
    return features

# %%
runBinaryClassifier(full_df, True)
# Out:
# Scores: [0.57012334 0.57925994 0.57906764 0.42184644 0.57998172]
# Mean: 0.5460558150566694
# Std: 0.06221009128407329
# Confusion: [[1350 3256]
#  [1711 4625]]

# %%
encoded_df = encodeFeatures(cleanFeatures(full_df)).copy()

relevant_df = pd.DataFrame()
relevant_df['Player Name'] = encoded_df['Player Name']
relevant_df['team'] = encoded_df['team']
relevant_df['Actual FP'] = encoded_df['Actual FP']
relevant_df['Selected'] = encoded_df['Selected']
relevant_df['Avg Proj'] = encoded_df['Avg Proj']
relevant_df['Salary'] = encoded_df['Salary']

relevant_df['implied_team_score'] = encoded_df['implied_team_score']


relevant_df['Avg Value Proj'] = ((encoded_df['DFN_ValueProj']+encoded_df['FantasyFuelValueProj'])/2)
relevant_df['Avg Skewed Min'] = ((encoded_df['L2 Min']+encoded_df['L5 Min']+encoded_df['S Min'])/3)
relevant_df['Avg Skewed FGA'] = ((encoded_df['L2 FGA']+encoded_df['L5 FGA']+encoded_df['S FGA'])/3)
relevant_df['Avg Skewed FP'] = ((encoded_df['L5 FP']+encoded_df['S FP']+encoded_df['Ceil FP']+encoded_df['Floor FP']+encoded_df['Avg Proj'])/5)
relevant_df['Avg L5 PPG'] = ((encoded_df['L5_ppg_floor']+encoded_df['L5_ppg_avg']+encoded_df['L5_ppg_max'])/3)

# %%
runBinaryClassifier(relevant_df, False)
# Out:
# Scores: [0.57880311 0.42074006 0.57906764 0.57906764 0.57906764]
# Mean: 0.5473492190886291
# Std: 0.06330466047357355
# Confusion: [[ 922 3684]
#  [1269 5067]]

# %%
relevant_df[relevant_df['implied_team_score']>110].hist(bins=50, figsize=(20,15))
plt.show()
